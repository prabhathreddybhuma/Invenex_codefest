# %%
import pandas as pd
from pymongo import MongoClient
import datetime

# --- Step 0: Connect to MongoDB ---
# Replace the connection string if using a different host or MongoDB Atlas.
client = MongoClient("mongodb+srv://himavarshithreddy:invenx@invenx.kxiph.mongodb.net/?retryWrites=true&w=majority&appName=InvenX")
db = client["InvenX"]

# --- Step 1: Retrieve Inventory Data ---
inventory_collection = db["inventory"]

# Retrieve all inventory documents with the required fields
inventory_docs = list(inventory_collection.find({}, {
    "_id": 0,
    "warehouse_id": 1,
    "product_id": 1,
    "current_stock": 1,
    "min_stock": 1,
    "max_stock": 1,
    "last_updated": 1,
    "forecast_value": 1
}))

# Convert the data into a pandas DataFrame
inventory_df = pd.DataFrame(inventory_docs)
print("Inventory Data:")
print(inventory_df)

# --- Step 2: Generate Inventory Optimization Recommendations ---
inventory_recommendations = {}

# For each inventory record, compare current_stock against forecast_value and thresholds
for idx, row in inventory_df.iterrows():
    product_id = row["product_id"]
    warehouse_id = row["warehouse_id"]
    current_stock = row["current_stock"]
    min_stock = row["min_stock"]
    max_stock = row["max_stock"]
    forecast_value = row.get("forecast_value")  # This is the forecasted demand

    recommendation = ""
    reorder_qty = 0

    # Check forecasted demand vs. current stock
    if forecast_value is not None:
        if current_stock < forecast_value:
            reorder_qty = forecast_value - current_stock
            recommendation += f"Reorder {reorder_qty} units. "

    # Check if stock is below the minimum threshold
    if current_stock < min_stock:
        recommendation += "Stock is below the minimum threshold! "

    # Check if stock exceeds the maximum threshold
    if current_stock > max_stock:
        recommendation += "Stock exceeds the maximum limit; consider reducing inventory. "

    if recommendation == "":
        recommendation = "Inventory levels are optimal."

    inventory_recommendations[(product_id, warehouse_id)] = {
        "current_stock": current_stock,
        "forecasted_demand": forecast_value,
        "recommendation": recommendation
    }

# --- Step 3: Print the Inventory Optimization Recommendations ---
print("\nInventory Optimization Recommendations:")
for (prod, ware), rec in inventory_recommendations.items():
    print(f"\nProduct {prod} in Warehouse {ware}:")
    print(f"  Current Stock: {rec['current_stock']}")
    print(f"  Forecasted Demand: {rec['forecasted_demand']}")
    print(f"  Recommendation: {rec['recommendation']}")
# Out:
# Inventory Data:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56        100        600
# 1        WIND01     P10002             43         75        400
# 2        WIND01     P10003             32        100        600
# 3        WIND01     P10004             62        100        600
# 4        WIND01     P10005             59         75        400
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15        100        600
# 66       WIND07     P10007             12        100        600
# 67       WIND07     P10008             27         50        200
# 68       WIND07     P10009             42        100        600
# 69       WIND07     P10010             53         75        400
#
#             last_updated  forecast_value
# 0   2025-02-10T10:00:00Z              63
# 1   2025-02-10T10:00:00Z              67
# 2   2025-02-10T10:00:00Z              65
# 3   2025-02-10T10:00:00Z              61
# 4   2025-02-10T10:00:00Z              26
# ..                   ...             ...
# 65  2025-02-10T10:00:00Z              47
# 66  2025-02-10T10:00:00Z             -34
# 67  2025-02-10T10:00:00Z              33
# 68  2025-02-10T10:00:00Z              47
# 69  2025-02-10T10:00:00Z              64
#
# [70 rows x 7 columns]
#
# Inventory Optimization Recommendations:
#
# Product P10001 in Warehouse WIND01:
#   Current Stock: 56
#   Forecasted Demand: 63
#   Recommendation: Reorder 7 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND01:
#   Current Stock: 43
#   Forecasted Demand: 67
#   Recommendation: Reorder 24 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND01:
#   Current Stock: 32
#   Forecasted Demand: 65
#   Recommendation: Reorder 33 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND01:
#   Current Stock: 62
#   Forecasted Demand: 61
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND01:
#   Current Stock: 59
#   Forecasted Demand: 26
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND01:
#   Current Stock: 47
#   Forecasted Demand: 80
#   Recommendation: Reorder 33 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND01:
#   Current Stock: 33
#   Forecasted Demand: 77
#   Recommendation: Reorder 44 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND01:
#   Current Stock: 87
#   Forecasted Demand: 23
#   Recommendation: Inventory levels are optimal.
#
# Product P10009 in Warehouse WIND01:
#   Current Stock: 99
#   Forecasted Demand: 98
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND01:
#   Current Stock: 25
#   Forecasted Demand: 43
#   Recommendation: Reorder 18 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND02:
#   Current Stock: 40
#   Forecasted Demand: 57
#   Recommendation: Reorder 17 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND02:
#   Current Stock: 10
#   Forecasted Demand: 68
#   Recommendation: Reorder 58 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND02:
#   Current Stock: 69
#   Forecasted Demand: 74
#   Recommendation: Reorder 5 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND02:
#   Current Stock: 73
#   Forecasted Demand: 49
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND02:
#   Current Stock: 84
#   Forecasted Demand: 48
#   Recommendation: Inventory levels are optimal.
#
# Product P10006 in Warehouse WIND02:
#   Current Stock: 94
#   Forecasted Demand: 17
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND02:
#   Current Stock: 67
#   Forecasted Demand: 49
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND02:
#   Current Stock: 77
#   Forecasted Demand: 52
#   Recommendation: Inventory levels are optimal.
#
# Product P10009 in Warehouse WIND02:
#   Current Stock: 63
#   Forecasted Demand: 45
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND02:
#   Current Stock: 43
#   Forecasted Demand: 118
#   Recommendation: Reorder 75 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND03:
#   Current Stock: 36
#   Forecasted Demand: 49
#   Recommendation: Reorder 13 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND03:
#   Current Stock: 91
#   Forecasted Demand: 53
#   Recommendation: Inventory levels are optimal.
#
# Product P10003 in Warehouse WIND03:
#   Current Stock: 45
#   Forecasted Demand: 76
#   Recommendation: Reorder 31 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND03:
#   Current Stock: 81
#   Forecasted Demand: 58
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND03:
#   Current Stock: 77
#   Forecasted Demand: 65
#   Recommendation: Inventory levels are optimal.
#
# Product P10006 in Warehouse WIND03:
#   Current Stock: 54
#   Forecasted Demand: 61
#   Recommendation: Reorder 7 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND03:
#   Current Stock: 35
#   Forecasted Demand: 77
#   Recommendation: Reorder 42 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND03:
#   Current Stock: 37
#   Forecasted Demand: 77
#   Recommendation: Reorder 40 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND03:
#   Current Stock: 73
#   Forecasted Demand: 48
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND03:
#   Current Stock: 28
#   Forecasted Demand: 112
#   Recommendation: Reorder 84 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND04:
#   Current Stock: 29
#   Forecasted Demand: 66
#   Recommendation: Reorder 37 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND04:
#   Current Stock: 37
#   Forecasted Demand: 33
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND04:
#   Current Stock: 66
#   Forecasted Demand: 56
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND04:
#   Current Stock: 40
#   Forecasted Demand: 78
#   Recommendation: Reorder 38 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND04:
#   Current Stock: 39
#   Forecasted Demand: 45
#   Recommendation: Reorder 6 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND04:
#   Current Stock: 54
#   Forecasted Demand: 88
#   Recommendation: Reorder 34 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND04:
#   Current Stock: 77
#   Forecasted Demand: 87
#   Recommendation: Reorder 10 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND04:
#   Current Stock: 49
#   Forecasted Demand: 68
#   Recommendation: Reorder 19 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND04:
#   Current Stock: 75
#   Forecasted Demand: 77
#   Recommendation: Reorder 2 units. Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND04:
#   Current Stock: 35
#   Forecasted Demand: 53
#   Recommendation: Reorder 18 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND05:
#   Current Stock: 88
#   Forecasted Demand: 47
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND05:
#   Current Stock: 72
#   Forecasted Demand: 49
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND05:
#   Current Stock: 66
#   Forecasted Demand: 48
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND05:
#   Current Stock: 51
#   Forecasted Demand: 84
#   Recommendation: Reorder 33 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND05:
#   Current Stock: 25
#   Forecasted Demand: 82
#   Recommendation: Reorder 57 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND05:
#   Current Stock: 31
#   Forecasted Demand: 43
#   Recommendation: Reorder 12 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND05:
#   Current Stock: 47
#   Forecasted Demand: 70
#   Recommendation: Reorder 23 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND05:
#   Current Stock: 52
#   Forecasted Demand: 5
#   Recommendation: Inventory levels are optimal.
#
# Product P10009 in Warehouse WIND05:
#   Current Stock: 33
#   Forecasted Demand: 51
#   Recommendation: Reorder 18 units. Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND05:
#   Current Stock: 58
#   Forecasted Demand: 48
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND06:
#   Current Stock: 80
#   Forecasted Demand: 77
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND06:
#   Current Stock: 63
#   Forecasted Demand: 74
#   Recommendation: Reorder 11 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND06:
#   Current Stock: 38
#   Forecasted Demand: 89
#   Recommendation: Reorder 51 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND06:
#   Current Stock: 26
#   Forecasted Demand: 90
#   Recommendation: Reorder 64 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND06:
#   Current Stock: 31
#   Forecasted Demand: 57
#   Recommendation: Reorder 26 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND06:
#   Current Stock: 47
#   Forecasted Demand: 63
#   Recommendation: Reorder 16 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND06:
#   Current Stock: 10
#   Forecasted Demand: 27
#   Recommendation: Reorder 17 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND06:
#   Current Stock: 45
#   Forecasted Demand: 75
#   Recommendation: Reorder 30 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND06:
#   Current Stock: 49
#   Forecasted Demand: 22
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND06:
#   Current Stock: 62
#   Forecasted Demand: 43
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND07:
#   Current Stock: 32
#   Forecasted Demand: 30
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: 68
#   Recommendation: Reorder 56 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND07:
#   Current Stock: 23
#   Forecasted Demand: 62
#   Recommendation: Reorder 39 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND07:
#   Current Stock: 43
#   Forecasted Demand: 69
#   Recommendation: Reorder 26 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND07:
#   Current Stock: 20
#   Forecasted Demand: 39
#   Recommendation: Reorder 19 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND07:
#   Current Stock: 15
#   Forecasted Demand: 47
#   Recommendation: Reorder 32 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: -34
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND07:
#   Current Stock: 27
#   Forecasted Demand: 33
#   Recommendation: Reorder 6 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND07:
#   Current Stock: 42
#   Forecasted Demand: 47
#   Recommendation: Reorder 5 units. Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND07:
#   Current Stock: 53
#   Forecasted Demand: 64
#   Recommendation: Reorder 11 units. Stock is below the minimum threshold!

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.11/dist-packages (4.11)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymongo) (2.7.0)

# %%
import pandas as pd

# Assuming inventory_df is already retrieved from MongoDB.
# inventory_df should have columns:
# ["warehouse_id", "product_id", "current_stock", "min_stock", "max_stock", "forecast_value", "last_updated"]

# For demonstration, let's print the inventory data:
print("Inventory Data:")
print(inventory_df)

# --- Part 1: Individual Warehouse Recommendations (as before) ---
inventory_recommendations = {}
for idx, row in inventory_df.iterrows():
    product_id = row["product_id"]
    warehouse_id = row["warehouse_id"]
    current_stock = row["current_stock"]
    min_stock = row["min_stock"]
    max_stock = row["max_stock"]
    forecast_value = row["forecast_value"]

    recommendation = ""
    reorder_qty = 0

    if forecast_value is not None:
        if current_stock < forecast_value:
            reorder_qty = forecast_value - current_stock
            recommendation += f"Reorder {reorder_qty} units. "

    if current_stock < min_stock:
        recommendation += "Stock is below the minimum threshold! "

    if current_stock > max_stock:
        recommendation += "Stock exceeds the maximum limit; consider reducing inventory. "

    if recommendation == "":
        recommendation = "Inventory levels are optimal."

    inventory_recommendations[(product_id, warehouse_id)] = {
        "current_stock": current_stock,
        "forecasted_demand": forecast_value,
        "recommendation": recommendation
    }

print("\nIndividual Inventory Recommendations:")
for (prod, ware), rec in inventory_recommendations.items():
    print(f"Product {prod} in Warehouse {ware}:")
    print(f"  Current Stock: {rec['current_stock']}")
    print(f"  Forecasted Demand: {rec['forecasted_demand']}")
    print(f"  Recommendation: {rec['recommendation']}\n")

# --- Part 2: Cross-Warehouse Transfer Recommendations ---
# Group the inventory data by product_id to analyze stock across warehouses for the same product.
transfer_recommendations = {}

# Group by product_id
grouped_by_product = inventory_df.groupby("product_id")

for product_id, group in grouped_by_product:
    # For each product, create lists for warehouses with surplus and those with deficit.
    # diff = current_stock - forecast_value
    surplus_list = []  # List of tuples: (warehouse_id, surplus_amount)
    deficit_list = []  # List of tuples: (warehouse_id, deficit_amount)

    for idx, row in group.iterrows():
        warehouse_id = row["warehouse_id"]
        current_stock = row["current_stock"]
        forecast_value = row["forecast_value"]
        diff = current_stock - forecast_value  # positive => surplus, negative => deficit

        if diff > 0:
            surplus_list.append((warehouse_id, diff))
        elif diff < 0:
            deficit_list.append((warehouse_id, -diff))  # store positive value for deficit

    # Now, for this product, match surplus to deficit:
    for d_idx, (def_warehouse, deficit_qty) in enumerate(deficit_list):
        # For each warehouse with a deficit, try to find a surplus to cover it.
        for s_idx, (surp_warehouse, surplus_qty) in enumerate(surplus_list):
            if surplus_qty > 0 and deficit_qty > 0:
                # Determine how much can be transferred:
                transfer_qty = min(surplus_qty, deficit_qty)
                # Save or accumulate recommendation: key as (product_id, from_warehouse, to_warehouse)
                key = (product_id, surp_warehouse, def_warehouse)
                if key not in transfer_recommendations:
                    transfer_recommendations[key] = 0
                transfer_recommendations[key] += transfer_qty

                # Update the surplus and deficit amounts:
                surplus_qty -= transfer_qty
                deficit_qty -= transfer_qty
                # Update the lists:
                surplus_list[s_idx] = (surp_warehouse, surplus_qty)
                deficit_list[d_idx] = (def_warehouse, deficit_qty)
                # If deficit is completely met, break out of inner loop
                if deficit_qty == 0:
                    break

# --- Part 3: Print Transfer Recommendations ---
print("\nCross-Warehouse Transfer Recommendations:")
if transfer_recommendations:
    for (prod, from_ware, to_ware), qty in transfer_recommendations.items():
        print(f"Product {prod}: Transfer {qty} units from Warehouse {from_ware} to Warehouse {to_ware}.")
else:
    print("No transfer recommendations. Inventory levels across warehouses are balanced or no matching surpluses and deficits were found.")
# Out:
# Inventory Data:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56        100        600
# 1        WIND01     P10002             43         75        400
# 2        WIND01     P10003             32        100        600
# 3        WIND01     P10004             62        100        600
# 4        WIND01     P10005             59         75        400
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15        100        600
# 66       WIND07     P10007             12        100        600
# 67       WIND07     P10008             27         50        200
# 68       WIND07     P10009             42        100        600
# 69       WIND07     P10010             53         75        400
#
#             last_updated  forecast_value
# 0   2025-02-10T10:00:00Z              63
# 1   2025-02-10T10:00:00Z              67
# 2   2025-02-10T10:00:00Z              65
# 3   2025-02-10T10:00:00Z              61
# 4   2025-02-10T10:00:00Z              26
# ..                   ...             ...
# 65  2025-02-10T10:00:00Z              47
# 66  2025-02-10T10:00:00Z             -34
# 67  2025-02-10T10:00:00Z              33
# 68  2025-02-10T10:00:00Z              47
# 69  2025-02-10T10:00:00Z              64
#
# [70 rows x 7 columns]
#
# Individual Inventory Recommendations:
# Product P10001 in Warehouse WIND01:
#   Current Stock: 56
#   Forecasted Demand: 63
#   Recommendation: Reorder 7 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND01:
#   Current Stock: 43
#   Forecasted Demand: 67
#   Recommendation: Reorder 24 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND01:
#   Current Stock: 32
#   Forecasted Demand: 65
#   Recommendation: Reorder 33 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND01:
#   Current Stock: 62
#   Forecasted Demand: 61
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND01:
#   Current Stock: 59
#   Forecasted Demand: 26
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND01:
#   Current Stock: 47
#   Forecasted Demand: 80
#   Recommendation: Reorder 33 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND01:
#   Current Stock: 33
#   Forecasted Demand: 77
#   Recommendation: Reorder 44 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND01:
#   Current Stock: 87
#   Forecasted Demand: 23
#   Recommendation: Inventory levels are optimal.
#
# Product P10009 in Warehouse WIND01:
#   Current Stock: 99
#   Forecasted Demand: 98
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND01:
#   Current Stock: 25
#   Forecasted Demand: 43
#   Recommendation: Reorder 18 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND02:
#   Current Stock: 40
#   Forecasted Demand: 57
#   Recommendation: Reorder 17 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND02:
#   Current Stock: 10
#   Forecasted Demand: 68
#   Recommendation: Reorder 58 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND02:
#   Current Stock: 69
#   Forecasted Demand: 74
#   Recommendation: Reorder 5 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND02:
#   Current Stock: 73
#   Forecasted Demand: 49
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND02:
#   Current Stock: 84
#   Forecasted Demand: 48
#   Recommendation: Inventory levels are optimal.
#
# Product P10006 in Warehouse WIND02:
#   Current Stock: 94
#   Forecasted Demand: 17
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND02:
#   Current Stock: 67
#   Forecasted Demand: 49
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND02:
#   Current Stock: 77
#   Forecasted Demand: 52
#   Recommendation: Inventory levels are optimal.
#
# Product P10009 in Warehouse WIND02:
#   Current Stock: 63
#   Forecasted Demand: 45
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND02:
#   Current Stock: 43
#   Forecasted Demand: 118
#   Recommendation: Reorder 75 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND03:
#   Current Stock: 36
#   Forecasted Demand: 49
#   Recommendation: Reorder 13 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND03:
#   Current Stock: 91
#   Forecasted Demand: 53
#   Recommendation: Inventory levels are optimal.
#
# Product P10003 in Warehouse WIND03:
#   Current Stock: 45
#   Forecasted Demand: 76
#   Recommendation: Reorder 31 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND03:
#   Current Stock: 81
#   Forecasted Demand: 58
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND03:
#   Current Stock: 77
#   Forecasted Demand: 65
#   Recommendation: Inventory levels are optimal.
#
# Product P10006 in Warehouse WIND03:
#   Current Stock: 54
#   Forecasted Demand: 61
#   Recommendation: Reorder 7 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND03:
#   Current Stock: 35
#   Forecasted Demand: 77
#   Recommendation: Reorder 42 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND03:
#   Current Stock: 37
#   Forecasted Demand: 77
#   Recommendation: Reorder 40 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND03:
#   Current Stock: 73
#   Forecasted Demand: 48
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND03:
#   Current Stock: 28
#   Forecasted Demand: 112
#   Recommendation: Reorder 84 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND04:
#   Current Stock: 29
#   Forecasted Demand: 66
#   Recommendation: Reorder 37 units. Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND04:
#   Current Stock: 37
#   Forecasted Demand: 33
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND04:
#   Current Stock: 66
#   Forecasted Demand: 56
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND04:
#   Current Stock: 40
#   Forecasted Demand: 78
#   Recommendation: Reorder 38 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND04:
#   Current Stock: 39
#   Forecasted Demand: 45
#   Recommendation: Reorder 6 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND04:
#   Current Stock: 54
#   Forecasted Demand: 88
#   Recommendation: Reorder 34 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND04:
#   Current Stock: 77
#   Forecasted Demand: 87
#   Recommendation: Reorder 10 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND04:
#   Current Stock: 49
#   Forecasted Demand: 68
#   Recommendation: Reorder 19 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND04:
#   Current Stock: 75
#   Forecasted Demand: 77
#   Recommendation: Reorder 2 units. Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND04:
#   Current Stock: 35
#   Forecasted Demand: 53
#   Recommendation: Reorder 18 units. Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND05:
#   Current Stock: 88
#   Forecasted Demand: 47
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND05:
#   Current Stock: 72
#   Forecasted Demand: 49
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND05:
#   Current Stock: 66
#   Forecasted Demand: 48
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND05:
#   Current Stock: 51
#   Forecasted Demand: 84
#   Recommendation: Reorder 33 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND05:
#   Current Stock: 25
#   Forecasted Demand: 82
#   Recommendation: Reorder 57 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND05:
#   Current Stock: 31
#   Forecasted Demand: 43
#   Recommendation: Reorder 12 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND05:
#   Current Stock: 47
#   Forecasted Demand: 70
#   Recommendation: Reorder 23 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND05:
#   Current Stock: 52
#   Forecasted Demand: 5
#   Recommendation: Inventory levels are optimal.
#
# Product P10009 in Warehouse WIND05:
#   Current Stock: 33
#   Forecasted Demand: 51
#   Recommendation: Reorder 18 units. Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND05:
#   Current Stock: 58
#   Forecasted Demand: 48
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND06:
#   Current Stock: 80
#   Forecasted Demand: 77
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND06:
#   Current Stock: 63
#   Forecasted Demand: 74
#   Recommendation: Reorder 11 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND06:
#   Current Stock: 38
#   Forecasted Demand: 89
#   Recommendation: Reorder 51 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND06:
#   Current Stock: 26
#   Forecasted Demand: 90
#   Recommendation: Reorder 64 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND06:
#   Current Stock: 31
#   Forecasted Demand: 57
#   Recommendation: Reorder 26 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND06:
#   Current Stock: 47
#   Forecasted Demand: 63
#   Recommendation: Reorder 16 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND06:
#   Current Stock: 10
#   Forecasted Demand: 27
#   Recommendation: Reorder 17 units. Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND06:
#   Current Stock: 45
#   Forecasted Demand: 75
#   Recommendation: Reorder 30 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND06:
#   Current Stock: 49
#   Forecasted Demand: 22
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND06:
#   Current Stock: 62
#   Forecasted Demand: 43
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10001 in Warehouse WIND07:
#   Current Stock: 32
#   Forecasted Demand: 30
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10002 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: 68
#   Recommendation: Reorder 56 units. Stock is below the minimum threshold!
#
# Product P10003 in Warehouse WIND07:
#   Current Stock: 23
#   Forecasted Demand: 62
#   Recommendation: Reorder 39 units. Stock is below the minimum threshold!
#
# Product P10004 in Warehouse WIND07:
#   Current Stock: 43
#   Forecasted Demand: 69
#   Recommendation: Reorder 26 units. Stock is below the minimum threshold!
#
# Product P10005 in Warehouse WIND07:
#   Current Stock: 20
#   Forecasted Demand: 39
#   Recommendation: Reorder 19 units. Stock is below the minimum threshold!
#
# Product P10006 in Warehouse WIND07:
#   Current Stock: 15
#   Forecasted Demand: 47
#   Recommendation: Reorder 32 units. Stock is below the minimum threshold!
#
# Product P10007 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: -34
#   Recommendation: Stock is below the minimum threshold!
#
# Product P10008 in Warehouse WIND07:
#   Current Stock: 27
#   Forecasted Demand: 33
#   Recommendation: Reorder 6 units. Stock is below the minimum threshold!
#
# Product P10009 in Warehouse WIND07:
#   Current Stock: 42
#   Forecasted Demand: 47
#   Recommendation: Reorder 5 units. Stock is below the minimum threshold!
#
# Product P10010 in Warehouse WIND07:
#   Current Stock: 53
#   Forecasted Demand: 64
#   Recommendation: Reorder 11 units. Stock is below the minimum threshold!
#
#
# Cross-Warehouse Transfer Recommendations:
# Product P10001: Transfer 7 units from Warehouse WIND05 to Warehouse WIND01.
# Product P10001: Transfer 17 units from Warehouse WIND05 to Warehouse WIND02.
# Product P10001: Transfer 13 units from Warehouse WIND05 to Warehouse WIND03.
# Product P10001: Transfer 4 units from Warehouse WIND05 to Warehouse WIND04.
# Product P10001: Transfer 3 units from Warehouse WIND06 to Warehouse WIND04.
# Product P10001: Transfer 2 units from Warehouse WIND07 to Warehouse WIND04.
# Product P10002: Transfer 24 units from Warehouse WIND03 to Warehouse WIND01.
# Product P10002: Transfer 14 units from Warehouse WIND03 to Warehouse WIND02.
# Product P10002: Transfer 4 units from Warehouse WIND04 to Warehouse WIND02.
# Product P10002: Transfer 23 units from Warehouse WIND05 to Warehouse WIND02.
# Product P10003: Transfer 10 units from Warehouse WIND04 to Warehouse WIND01.
# Product P10003: Transfer 18 units from Warehouse WIND05 to Warehouse WIND01.
# Product P10004: Transfer 1 units from Warehouse WIND01 to Warehouse WIND04.
# Product P10004: Transfer 24 units from Warehouse WIND02 to Warehouse WIND04.
# Product P10004: Transfer 13 units from Warehouse WIND03 to Warehouse WIND04.
# Product P10004: Transfer 10 units from Warehouse WIND03 to Warehouse WIND05.
# Product P10005: Transfer 6 units from Warehouse WIND01 to Warehouse WIND04.
# Product P10005: Transfer 27 units from Warehouse WIND01 to Warehouse WIND05.
# Product P10005: Transfer 30 units from Warehouse WIND02 to Warehouse WIND05.
# Product P10005: Transfer 6 units from Warehouse WIND02 to Warehouse WIND06.
# Product P10005: Transfer 12 units from Warehouse WIND03 to Warehouse WIND06.
# Product P10006: Transfer 33 units from Warehouse WIND02 to Warehouse WIND01.
# Product P10006: Transfer 7 units from Warehouse WIND02 to Warehouse WIND03.
# Product P10006: Transfer 34 units from Warehouse WIND02 to Warehouse WIND04.
# Product P10006: Transfer 3 units from Warehouse WIND02 to Warehouse WIND05.
# Product P10007: Transfer 18 units from Warehouse WIND02 to Warehouse WIND01.
# Product P10007: Transfer 26 units from Warehouse WIND07 to Warehouse WIND01.
# Product P10007: Transfer 20 units from Warehouse WIND07 to Warehouse WIND03.
# Product P10008: Transfer 40 units from Warehouse WIND01 to Warehouse WIND03.
# Product P10008: Transfer 19 units from Warehouse WIND01 to Warehouse WIND04.
# Product P10008: Transfer 5 units from Warehouse WIND01 to Warehouse WIND06.
# Product P10008: Transfer 25 units from Warehouse WIND02 to Warehouse WIND06.
# Product P10008: Transfer 6 units from Warehouse WIND05 to Warehouse WIND07.
# Product P10009: Transfer 1 units from Warehouse WIND01 to Warehouse WIND04.
# Product P10009: Transfer 1 units from Warehouse WIND02 to Warehouse WIND04.
# Product P10009: Transfer 17 units from Warehouse WIND02 to Warehouse WIND05.
# Product P10009: Transfer 1 units from Warehouse WIND03 to Warehouse WIND05.
# Product P10009: Transfer 5 units from Warehouse WIND03 to Warehouse WIND07.
# Product P10010: Transfer 10 units from Warehouse WIND05 to Warehouse WIND01.
# Product P10010: Transfer 8 units from Warehouse WIND06 to Warehouse WIND01.
# Product P10010: Transfer 11 units from Warehouse WIND06 to Warehouse WIND02.

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
import datetime

# -------------------------
# MongoDB Connection
# -------------------------
connection_string = "mongodb+srv://himavarshithreddy:invenx@invenx.kxiph.mongodb.net/?retryWrites=true&w=majority&appName=InvenX"
client = MongoClient(connection_string)
db = client["InvenX"]

# -------------------------
# Retrieve Inventory Data
# -------------------------
inventory_collection = db["inventory"]
inventory_docs = list(inventory_collection.find({}, {
    "_id": 0,
    "warehouse_id": 1,
    "product_id": 1,
    "current_stock": 1,
    "min_stock": 1,
    "max_stock": 1,
    "last_updated": 1,
    "forecast_value": 1
}))
inventory_df = pd.DataFrame(inventory_docs)
print("Inventory Data:")
print(inventory_df)

# -------------------------
# Retrieve Warehouses Data (for ordering_cost)
# -------------------------
warehouses_collection = db["warehouses"]
warehouse_docs = list(warehouses_collection.find({}, {
    "_id": 1,           # Assuming the _id is used as the warehouse identifier
    "ordering_cost": 1
}))
warehouses_df = pd.DataFrame(warehouse_docs)
if not warehouses_df.empty:
    # Rename _id to warehouse_id if needed.
    if "_id" in warehouses_df.columns:
        warehouses_df = warehouses_df.rename(columns={"_id": "warehouse_id"})
else:
    print("Warning: Warehouses Data is empty; using default ordering cost.")

print("\nWarehouses Data:")
print(warehouses_df)

# -------------------------
# Retrieve Warehouse Transfers Data (for transfer cost)
# -------------------------
warehouse_transfers_collection = db["warehouse_transfers"]
warehouse_transfers_docs = list(warehouse_transfers_collection.find({}, {
    "_id": 0,
    "source_warehouse_id": 1,
    "destination_warehouse_id": 1,
    "transfer_cost": 1,
    "currency": 1,
    "estimated_transfer_time": 1
}))
warehouse_transfers_df = pd.DataFrame(warehouse_transfers_docs)
print("\nWarehouse Transfers Data:")
print(warehouse_transfers_df)

# -------------------------
# Merge Inventory with Warehouses Data to Include Ordering Cost
# -------------------------
default_ordering_cost = 2000.0  # Default ordering cost if warehouses data is missing
if warehouses_df.empty:
    inventory_df["ordering_cost"] = default_ordering_cost
else:
    inventory_df = pd.merge(inventory_df, warehouses_df[["warehouse_id", "ordering_cost"]],
                              on="warehouse_id", how="left")
    inventory_df["ordering_cost"] = inventory_df["ordering_cost"].fillna(default_ordering_cost)

print("\nInventory Data after merging ordering cost:")
print(inventory_df)

# -------------------------
# Configuration: Cost Parameters
# -------------------------
per_unit_order_cost = 5.0         # Cost per unit ordered (rupees)
external_transport_cost = 20.0    # External transportation cost (rupees)
holding_cost_per_unit_day = 0.5   # Holding cost per unit per day (rupees)
forecast_period_days = 7          # Forecast period (in days)
default_per_unit_transfer_cost = 15.0  # Default per-unit transfer cost if no transfer record found

# -------------------------
# Step 1: Compute Difference between Current Stock and Forecasted Demand
# -------------------------
# Using forecast_value as the target demand.
inventory_df['diff'] = inventory_df['current_stock'] - inventory_df['forecast_value']

# -------------------------
# Step 2: Individual Warehouse Recommendations
# -------------------------
individual_recommendations = {}

for idx, row in inventory_df.iterrows():
    prod = row["product_id"]
    ware = row["warehouse_id"]
    current_stock = row["current_stock"]
    forecast_value = row["forecast_value"]
    diff = row["diff"]
    min_stock = row["min_stock"]
    max_stock = row["max_stock"]
    order_cost = row["ordering_cost"]

    rec_message = ""
    external_order_cost = None

    if current_stock < forecast_value:
        deficit = forecast_value - current_stock
        # Calculate external ordering cost:
        external_order_cost = (order_cost +
                               (per_unit_order_cost * deficit) +
                               external_transport_cost +
                               (holding_cost_per_unit_day * forecast_period_days * deficit))
        rec_message += f"Needs to order {deficit:.0f} units externally (Cost: {external_order_cost:.2f} rupees). "
    else:
        surplus = current_stock - forecast_value
        rec_message += f"Has excess of {surplus:.0f} units; consider transfer. "

    # Additional alerts based on fixed thresholds.
    if current_stock < min_stock:
        rec_message += "Stock is below the fixed minimum threshold! "
    if current_stock > max_stock:
        rec_message += "Stock exceeds the maximum limit; consider reducing inventory. "

    if rec_message == "":
        rec_message = "Inventory levels are optimal."

    individual_recommendations[(prod, ware)] = {
        "current_stock": current_stock,
        "forecast_value": forecast_value,
        "diff": diff,
        "external_order_cost": external_order_cost,
        "recommendation": rec_message
    }

print("\nIndividual Inventory Recommendations:")
for (prod, ware), rec in individual_recommendations.items():
    print(f"\nProduct {prod} in Warehouse {ware}:")
    print(f"  Current Stock: {rec['current_stock']}")
    print(f"  Forecasted Demand: {rec['forecast_value']}")
    print(f"  Diff (Current - Forecast): {rec['diff']:.2f}")
    print(f"  External Ordering Cost: {rec['external_order_cost']}")
    print(f"  Recommendation: {rec['recommendation']}")

# -------------------------
# Step 3: Cross-Warehouse Transfer Recommendations
# -------------------------
transfer_recommendations = {}

# Group inventory data by product_id for cross-warehouse analysis.
for prod, group in inventory_df.groupby("product_id"):
    surplus_list = []  # Each element: (warehouse_id, surplus_amount)
    deficit_list = []  # Each element: (warehouse_id, deficit_amount)

    for idx, row in group.iterrows():
        wh = row["warehouse_id"]
        diff = row["diff"]
        if diff > 0:
            surplus_list.append((wh, diff))
        elif diff < 0:
            deficit_list.append((wh, -diff))  # Convert deficit to positive number

    # Match deficits with available surplus for the same product.
    for d_idx, (def_wh, def_qty) in enumerate(deficit_list):
        for s_idx, (surp_wh, surp_qty) in enumerate(surplus_list):
            if surp_qty > 0 and def_qty > 0:
                transfer_qty = min(surp_qty, def_qty)
                # Look up a transfer record for these warehouses.
                transfer_record = warehouse_transfers_df[
                    (warehouse_transfers_df["source_warehouse_id"] == surp_wh) &
                    (warehouse_transfers_df["destination_warehouse_id"] == def_wh)
                ]
                if not transfer_record.empty:
                    # Use the transfer cost from the record.
                    transfer_cost = float(transfer_record.iloc[0]["transfer_cost"]) * transfer_qty
                else:
                    # Use the default per-unit transfer cost.
                    transfer_cost = default_per_unit_transfer_cost * transfer_qty

                # Get the external ordering cost for the deficit warehouse (if available) from individual_recommendations.
                ext_order_cost = individual_recommendations.get((prod, def_wh), {}).get("external_order_cost", np.inf)

                # Decide on the recommendation based on cost.
                if transfer_cost < ext_order_cost:
                    rec_text = f"Transfer {transfer_qty:.0f} units from Warehouse {surp_wh} to Warehouse {def_wh} (Transfer Cost: {transfer_cost:.2f} rupees)."
                else:
                    rec_text = f"Order {def_qty:.0f} units externally for Warehouse {def_wh} (External Cost: {ext_order_cost:.2f} rupees)."

                key = (prod, surp_wh, def_wh)
                # We can store the recommended transfer/order quantity and cost.
                transfer_recommendations[key] = {
                    "transfer_qty": transfer_qty,
                    "transfer_cost": transfer_cost,
                    "external_order_cost": ext_order_cost,
                    "recommendation": rec_text
                }

                # Update the surplus and deficit amounts.
                surplus_list[s_idx] = (surp_wh, surp_qty - transfer_qty)
                deficit_list[d_idx] = (def_wh, def_qty - transfer_qty)
                if deficit_list[d_idx][1] == 0:
                    break

print("\nCross-Warehouse Transfer Recommendations:")
if transfer_recommendations:
    for (prod, from_wh, to_wh), info in transfer_recommendations.items():
        print(f"Product {prod}: {info['recommendation']}")
else:
    print("No internal transfer recommendations available.")
# Out:
# Inventory Data:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56          9        100
# 1        WIND01     P10002             43         10        100
# 2        WIND01     P10003             32         15        100
# 3        WIND01     P10004             29          9        100
# 4        WIND01     P10005             59          7        100
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15        100        600
# 66       WIND07     P10007             12        100        600
# 67       WIND07     P10008             27         50        200
# 68       WIND07     P10009             42        100        600
# 69       WIND07     P10010             53         75        400
#
#             last_updated  forecast_value
# 0   2025-02-10T10:00:00Z              63
# 1   2025-02-10T10:00:00Z              67
# 2   2025-02-10T10:00:00Z              65
# 3   2025-02-10T10:00:00Z              61
# 4   2025-02-10T10:00:00Z              26
# ..                   ...             ...
# 65  2025-02-10T10:00:00Z              47
# 66  2025-02-10T10:00:00Z             -34
# 67  2025-02-10T10:00:00Z              33
# 68  2025-02-10T10:00:00Z              47
# 69  2025-02-10T10:00:00Z              64
#
# [70 rows x 7 columns]
# Warning: Warehouses Data is empty; using default ordering cost.
#
# Warehouses Data:
# Empty DataFrame
# Columns: []
# Index: []
#
# Warehouse Transfers Data:
#    source_warehouse_id destination_warehouse_id  transfer_cost currency  \
# 0               WIND01                   WIND02           2000      INR
# 1               WIND01                   WIND03           1500      INR
# 2               WIND01                   WIND04           1200      INR
# 3               WIND01                   WIND05           1300      INR
# 4               WIND01                   WIND06           1800      INR
# 5               WIND01                   WIND07            500      INR
# 6               WIND02                   WIND01           2000      INR
# 7               WIND02                   WIND03           2200      INR
# 8               WIND02                   WIND04           2000      INR
# 9               WIND02                   WIND05           2100      INR
# 10              WIND02                   WIND06           1500      INR
# 11              WIND02                   WIND07           1900      INR
# 12              WIND03                   WIND01           1500      INR
# 13              WIND03                   WIND02           2200      INR
# 14              WIND03                   WIND04            800      INR
# 15              WIND03                   WIND05            900      INR
# 16              WIND03                   WIND06           1700      INR
# 17              WIND03                   WIND07           1000      INR
# 18              WIND04                   WIND01           1200      INR
# 19              WIND04                   WIND02           2000      INR
# 20              WIND04                   WIND03            800      INR
# 21              WIND04                   WIND05            700      INR
# 22              WIND04                   WIND06           1600      INR
# 23              WIND04                   WIND07            900      INR
# 24              WIND05                   WIND01           1300      INR
# 25              WIND05                   WIND02           2100      INR
# 26              WIND05                   WIND03            900      INR
# 27              WIND05                   WIND04            700      INR
# 28              WIND05                   WIND06           1800      INR
# 29              WIND05                   WIND07           1100      INR
# 30              WIND06                   WIND01           1800      INR
# 31              WIND06                   WIND02           1500      INR
# 32              WIND06                   WIND03           1700      INR
# 33              WIND06                   WIND04           1600      INR
# 34              WIND06                   WIND05           1800      INR
# 35              WIND06                   WIND07           1900      INR
# 36              WIND07                   WIND01            500      INR
# 37              WIND07                   WIND02           1900      INR
# 38              WIND07                   WIND03           1000      INR
# 39              WIND07                   WIND04            900      INR
# 40              WIND07                   WIND05           1100      INR
# 41              WIND07                   WIND06           1900      INR
#
#    estimated_transfer_time
# 0                   2 days
# 1                   2 days
# 2                 1.5 days
# 3                   2 days
# 4                   2 days
# 5                    1 day
# 6                   2 days
# 7                   2 days
# 8                   2 days
# 9                   2 days
# 10                1.5 days
# 11                  2 days
# 12                  2 days
# 13                  2 days
# 14                   1 day
# 15                   1 day
# 16                  2 days
# 17                   1 day
# 18                1.5 days
# 19                  2 days
# 20                   1 day
# 21                   1 day
# 22                  2 days
# 23                   1 day
# 24                  2 days
# 25                  2 days
# 26                   1 day
# 27                   1 day
# 28                  2 days
# 29                1.5 days
# 30                  2 days
# 31                1.5 days
# 32                  2 days
# 33                  2 days
# 34                  2 days
# 35                  2 days
# 36                   1 day
# 37                  2 days
# 38                   1 day
# 39                   1 day
# 40                1.5 days
# 41                  2 days
#
# Inventory Data after merging ordering cost:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56          9        100
# 1        WIND01     P10002             43         10        100
# 2        WIND01     P10003             32         15        100
# 3        WIND01     P10004             29          9        100
# 4        WIND01     P10005             59          7        100
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15        100        600
# 66       WIND07     P10007             12        100        600
# 67       WIND07     P10008             27         50        200
# 68       WIND07     P10009             42        100        600
# 69       WIND07     P10010             53         75        400
#
#             last_updated  forecast_value  ordering_cost
# 0   2025-02-10T10:00:00Z              63         2000.0
# 1   2025-02-10T10:00:00Z              67         2000.0
# 2   2025-02-10T10:00:00Z              65         2000.0
# 3   2025-02-10T10:00:00Z              61         2000.0
# 4   2025-02-10T10:00:00Z              26         2000.0
# ..                   ...             ...            ...
# 65  2025-02-10T10:00:00Z              47         2000.0
# 66  2025-02-10T10:00:00Z             -34         2000.0
# 67  2025-02-10T10:00:00Z              33         2000.0
# 68  2025-02-10T10:00:00Z              47         2000.0
# 69  2025-02-10T10:00:00Z              64         2000.0
#
# [70 rows x 8 columns]
#
# Individual Inventory Recommendations:
#
# Product P10001 in Warehouse WIND01:
#   Current Stock: 56
#   Forecasted Demand: 63
#   Diff (Current - Forecast): -7.00
#   External Ordering Cost: 2079.5
#   Recommendation: Needs to order 7 units externally (Cost: 2079.50 rupees).
#
# Product P10002 in Warehouse WIND01:
#   Current Stock: 43
#   Forecasted Demand: 67
#   Diff (Current - Forecast): -24.00
#   External Ordering Cost: 2224.0
#   Recommendation: Needs to order 24 units externally (Cost: 2224.00 rupees).
#
# Product P10003 in Warehouse WIND01:
#   Current Stock: 32
#   Forecasted Demand: 65
#   Diff (Current - Forecast): -33.00
#   External Ordering Cost: 2300.5
#   Recommendation: Needs to order 33 units externally (Cost: 2300.50 rupees).
#
# Product P10004 in Warehouse WIND01:
#   Current Stock: 29
#   Forecasted Demand: 61
#   Diff (Current - Forecast): -32.00
#   External Ordering Cost: 2292.0
#   Recommendation: Needs to order 32 units externally (Cost: 2292.00 rupees).
#
# Product P10005 in Warehouse WIND01:
#   Current Stock: 59
#   Forecasted Demand: 26
#   Diff (Current - Forecast): 33.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 33 units; consider transfer.
#
# Product P10006 in Warehouse WIND01:
#   Current Stock: 47
#   Forecasted Demand: 80
#   Diff (Current - Forecast): -33.00
#   External Ordering Cost: 2300.5
#   Recommendation: Needs to order 33 units externally (Cost: 2300.50 rupees).
#
# Product P10007 in Warehouse WIND01:
#   Current Stock: 33
#   Forecasted Demand: 77
#   Diff (Current - Forecast): -44.00
#   External Ordering Cost: 2394.0
#   Recommendation: Needs to order 44 units externally (Cost: 2394.00 rupees).
#
# Product P10008 in Warehouse WIND01:
#   Current Stock: 87
#   Forecasted Demand: 23
#   Diff (Current - Forecast): 64.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 64 units; consider transfer.
#
# Product P10009 in Warehouse WIND01:
#   Current Stock: 99
#   Forecasted Demand: 98
#   Diff (Current - Forecast): 1.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 1 units; consider transfer.
#
# Product P10010 in Warehouse WIND01:
#   Current Stock: 25
#   Forecasted Demand: 43
#   Diff (Current - Forecast): -18.00
#   External Ordering Cost: 2173.0
#   Recommendation: Needs to order 18 units externally (Cost: 2173.00 rupees).
#
# Product P10001 in Warehouse WIND02:
#   Current Stock: 40
#   Forecasted Demand: 57
#   Diff (Current - Forecast): -17.00
#   External Ordering Cost: 2164.5
#   Recommendation: Needs to order 17 units externally (Cost: 2164.50 rupees).
#
# Product P10002 in Warehouse WIND02:
#   Current Stock: 10
#   Forecasted Demand: 68
#   Diff (Current - Forecast): -58.00
#   External Ordering Cost: 2513.0
#   Recommendation: Needs to order 58 units externally (Cost: 2513.00 rupees).
#
# Product P10003 in Warehouse WIND02:
#   Current Stock: 69
#   Forecasted Demand: 74
#   Diff (Current - Forecast): -5.00
#   External Ordering Cost: 2062.5
#   Recommendation: Needs to order 5 units externally (Cost: 2062.50 rupees).
#
# Product P10004 in Warehouse WIND02:
#   Current Stock: 73
#   Forecasted Demand: 49
#   Diff (Current - Forecast): 24.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 24 units; consider transfer.
#
# Product P10005 in Warehouse WIND02:
#   Current Stock: 84
#   Forecasted Demand: 48
#   Diff (Current - Forecast): 36.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 36 units; consider transfer.
#
# Product P10006 in Warehouse WIND02:
#   Current Stock: 94
#   Forecasted Demand: 17
#   Diff (Current - Forecast): 77.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 77 units; consider transfer.
#
# Product P10007 in Warehouse WIND02:
#   Current Stock: 19
#   Forecasted Demand: 49
#   Diff (Current - Forecast): -30.00
#   External Ordering Cost: 2275.0
#   Recommendation: Needs to order 30 units externally (Cost: 2275.00 rupees).
#
# Product P10008 in Warehouse WIND02:
#   Current Stock: 77
#   Forecasted Demand: 52
#   Diff (Current - Forecast): 25.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 25 units; consider transfer.
#
# Product P10009 in Warehouse WIND02:
#   Current Stock: 63
#   Forecasted Demand: 45
#   Diff (Current - Forecast): 18.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 18 units; consider transfer.
#
# Product P10010 in Warehouse WIND02:
#   Current Stock: 43
#   Forecasted Demand: 118
#   Diff (Current - Forecast): -75.00
#   External Ordering Cost: 2657.5
#   Recommendation: Needs to order 75 units externally (Cost: 2657.50 rupees).
#
# Product P10001 in Warehouse WIND03:
#   Current Stock: 36
#   Forecasted Demand: 49
#   Diff (Current - Forecast): -13.00
#   External Ordering Cost: 2130.5
#   Recommendation: Needs to order 13 units externally (Cost: 2130.50 rupees).
#
# Product P10002 in Warehouse WIND03:
#   Current Stock: 91
#   Forecasted Demand: 53
#   Diff (Current - Forecast): 38.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 38 units; consider transfer.
#
# Product P10003 in Warehouse WIND03:
#   Current Stock: 45
#   Forecasted Demand: 76
#   Diff (Current - Forecast): -31.00
#   External Ordering Cost: 2283.5
#   Recommendation: Needs to order 31 units externally (Cost: 2283.50 rupees).
#
# Product P10004 in Warehouse WIND03:
#   Current Stock: 81
#   Forecasted Demand: 58
#   Diff (Current - Forecast): 23.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 23 units; consider transfer.
#
# Product P10005 in Warehouse WIND03:
#   Current Stock: 77
#   Forecasted Demand: 65
#   Diff (Current - Forecast): 12.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 12 units; consider transfer.
#
# Product P10006 in Warehouse WIND03:
#   Current Stock: 54
#   Forecasted Demand: 61
#   Diff (Current - Forecast): -7.00
#   External Ordering Cost: 2079.5
#   Recommendation: Needs to order 7 units externally (Cost: 2079.50 rupees).
#
# Product P10007 in Warehouse WIND03:
#   Current Stock: 35
#   Forecasted Demand: 77
#   Diff (Current - Forecast): -42.00
#   External Ordering Cost: 2377.0
#   Recommendation: Needs to order 42 units externally (Cost: 2377.00 rupees).
#
# Product P10008 in Warehouse WIND03:
#   Current Stock: 37
#   Forecasted Demand: 77
#   Diff (Current - Forecast): -40.00
#   External Ordering Cost: 2360.0
#   Recommendation: Needs to order 40 units externally (Cost: 2360.00 rupees).
#
# Product P10009 in Warehouse WIND03:
#   Current Stock: 73
#   Forecasted Demand: 48
#   Diff (Current - Forecast): 25.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 25 units; consider transfer.
#
# Product P10010 in Warehouse WIND03:
#   Current Stock: 28
#   Forecasted Demand: 112
#   Diff (Current - Forecast): -84.00
#   External Ordering Cost: 2734.0
#   Recommendation: Needs to order 84 units externally (Cost: 2734.00 rupees).
#
# Product P10001 in Warehouse WIND04:
#   Current Stock: 29
#   Forecasted Demand: 66
#   Diff (Current - Forecast): -37.00
#   External Ordering Cost: 2334.5
#   Recommendation: Needs to order 37 units externally (Cost: 2334.50 rupees).
#
# Product P10002 in Warehouse WIND04:
#   Current Stock: 37
#   Forecasted Demand: 33
#   Diff (Current - Forecast): 4.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 4 units; consider transfer.
#
# Product P10003 in Warehouse WIND04:
#   Current Stock: 66
#   Forecasted Demand: 56
#   Diff (Current - Forecast): 10.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 10 units; consider transfer.
#
# Product P10004 in Warehouse WIND04:
#   Current Stock: 40
#   Forecasted Demand: 78
#   Diff (Current - Forecast): -38.00
#   External Ordering Cost: 2343.0
#   Recommendation: Needs to order 38 units externally (Cost: 2343.00 rupees).
#
# Product P10005 in Warehouse WIND04:
#   Current Stock: 39
#   Forecasted Demand: 45
#   Diff (Current - Forecast): -6.00
#   External Ordering Cost: 2071.0
#   Recommendation: Needs to order 6 units externally (Cost: 2071.00 rupees).
#
# Product P10006 in Warehouse WIND04:
#   Current Stock: 54
#   Forecasted Demand: 88
#   Diff (Current - Forecast): -34.00
#   External Ordering Cost: 2309.0
#   Recommendation: Needs to order 34 units externally (Cost: 2309.00 rupees).
#
# Product P10007 in Warehouse WIND04:
#   Current Stock: 77
#   Forecasted Demand: 87
#   Diff (Current - Forecast): -10.00
#   External Ordering Cost: 2105.0
#   Recommendation: Needs to order 10 units externally (Cost: 2105.00 rupees).
#
# Product P10008 in Warehouse WIND04:
#   Current Stock: 49
#   Forecasted Demand: 68
#   Diff (Current - Forecast): -19.00
#   External Ordering Cost: 2181.5
#   Recommendation: Needs to order 19 units externally (Cost: 2181.50 rupees).
#
# Product P10009 in Warehouse WIND04:
#   Current Stock: 75
#   Forecasted Demand: 77
#   Diff (Current - Forecast): -2.00
#   External Ordering Cost: 2037.0
#   Recommendation: Needs to order 2 units externally (Cost: 2037.00 rupees).
#
# Product P10010 in Warehouse WIND04:
#   Current Stock: 35
#   Forecasted Demand: 53
#   Diff (Current - Forecast): -18.00
#   External Ordering Cost: 2173.0
#   Recommendation: Needs to order 18 units externally (Cost: 2173.00 rupees).
#
# Product P10001 in Warehouse WIND05:
#   Current Stock: 88
#   Forecasted Demand: 47
#   Diff (Current - Forecast): 41.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 41 units; consider transfer.
#
# Product P10002 in Warehouse WIND05:
#   Current Stock: 72
#   Forecasted Demand: 49
#   Diff (Current - Forecast): 23.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 23 units; consider transfer.
#
# Product P10003 in Warehouse WIND05:
#   Current Stock: 66
#   Forecasted Demand: 48
#   Diff (Current - Forecast): 18.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 18 units; consider transfer.
#
# Product P10004 in Warehouse WIND05:
#   Current Stock: 51
#   Forecasted Demand: 84
#   Diff (Current - Forecast): -33.00
#   External Ordering Cost: 2300.5
#   Recommendation: Needs to order 33 units externally (Cost: 2300.50 rupees).
#
# Product P10005 in Warehouse WIND05:
#   Current Stock: 25
#   Forecasted Demand: 82
#   Diff (Current - Forecast): -57.00
#   External Ordering Cost: 2504.5
#   Recommendation: Needs to order 57 units externally (Cost: 2504.50 rupees).
#
# Product P10006 in Warehouse WIND05:
#   Current Stock: 31
#   Forecasted Demand: 43
#   Diff (Current - Forecast): -12.00
#   External Ordering Cost: 2122.0
#   Recommendation: Needs to order 12 units externally (Cost: 2122.00 rupees).
#
# Product P10007 in Warehouse WIND05:
#   Current Stock: 47
#   Forecasted Demand: 70
#   Diff (Current - Forecast): -23.00
#   External Ordering Cost: 2215.5
#   Recommendation: Needs to order 23 units externally (Cost: 2215.50 rupees).
#
# Product P10008 in Warehouse WIND05:
#   Current Stock: 52
#   Forecasted Demand: 5
#   Diff (Current - Forecast): 47.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 47 units; consider transfer.
#
# Product P10009 in Warehouse WIND05:
#   Current Stock: 33
#   Forecasted Demand: 51
#   Diff (Current - Forecast): -18.00
#   External Ordering Cost: 2173.0
#   Recommendation: Needs to order 18 units externally (Cost: 2173.00 rupees).
#
# Product P10010 in Warehouse WIND05:
#   Current Stock: 58
#   Forecasted Demand: 48
#   Diff (Current - Forecast): 10.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 10 units; consider transfer.
#
# Product P10001 in Warehouse WIND06:
#   Current Stock: 80
#   Forecasted Demand: 77
#   Diff (Current - Forecast): 3.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 3 units; consider transfer. Stock is below the fixed minimum threshold!
#
# Product P10002 in Warehouse WIND06:
#   Current Stock: 63
#   Forecasted Demand: 74
#   Diff (Current - Forecast): -11.00
#   External Ordering Cost: 2113.5
#   Recommendation: Needs to order 11 units externally (Cost: 2113.50 rupees). Stock is below the fixed minimum threshold!
#
# Product P10003 in Warehouse WIND06:
#   Current Stock: 38
#   Forecasted Demand: 89
#   Diff (Current - Forecast): -51.00
#   External Ordering Cost: 2453.5
#   Recommendation: Needs to order 51 units externally (Cost: 2453.50 rupees). Stock is below the fixed minimum threshold!
#
# Product P10004 in Warehouse WIND06:
#   Current Stock: 26
#   Forecasted Demand: 90
#   Diff (Current - Forecast): -64.00
#   External Ordering Cost: 2564.0
#   Recommendation: Needs to order 64 units externally (Cost: 2564.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10005 in Warehouse WIND06:
#   Current Stock: 31
#   Forecasted Demand: 57
#   Diff (Current - Forecast): -26.00
#   External Ordering Cost: 2241.0
#   Recommendation: Needs to order 26 units externally (Cost: 2241.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10006 in Warehouse WIND06:
#   Current Stock: 47
#   Forecasted Demand: 63
#   Diff (Current - Forecast): -16.00
#   External Ordering Cost: 2156.0
#   Recommendation: Needs to order 16 units externally (Cost: 2156.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10007 in Warehouse WIND06:
#   Current Stock: 10
#   Forecasted Demand: 27
#   Diff (Current - Forecast): -17.00
#   External Ordering Cost: 2164.5
#   Recommendation: Needs to order 17 units externally (Cost: 2164.50 rupees). Stock is below the fixed minimum threshold!
#
# Product P10008 in Warehouse WIND06:
#   Current Stock: 45
#   Forecasted Demand: 75
#   Diff (Current - Forecast): -30.00
#   External Ordering Cost: 2275.0
#   Recommendation: Needs to order 30 units externally (Cost: 2275.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10009 in Warehouse WIND06:
#   Current Stock: 49
#   Forecasted Demand: 22
#   Diff (Current - Forecast): 27.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 27 units; consider transfer. Stock is below the fixed minimum threshold!
#
# Product P10010 in Warehouse WIND06:
#   Current Stock: 62
#   Forecasted Demand: 43
#   Diff (Current - Forecast): 19.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 19 units; consider transfer. Stock is below the fixed minimum threshold!
#
# Product P10001 in Warehouse WIND07:
#   Current Stock: 32
#   Forecasted Demand: 30
#   Diff (Current - Forecast): 2.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 2 units; consider transfer. Stock is below the fixed minimum threshold!
#
# Product P10002 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: 68
#   Diff (Current - Forecast): -56.00
#   External Ordering Cost: 2496.0
#   Recommendation: Needs to order 56 units externally (Cost: 2496.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10003 in Warehouse WIND07:
#   Current Stock: 23
#   Forecasted Demand: 62
#   Diff (Current - Forecast): -39.00
#   External Ordering Cost: 2351.5
#   Recommendation: Needs to order 39 units externally (Cost: 2351.50 rupees). Stock is below the fixed minimum threshold!
#
# Product P10004 in Warehouse WIND07:
#   Current Stock: 43
#   Forecasted Demand: 69
#   Diff (Current - Forecast): -26.00
#   External Ordering Cost: 2241.0
#   Recommendation: Needs to order 26 units externally (Cost: 2241.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10005 in Warehouse WIND07:
#   Current Stock: 20
#   Forecasted Demand: 39
#   Diff (Current - Forecast): -19.00
#   External Ordering Cost: 2181.5
#   Recommendation: Needs to order 19 units externally (Cost: 2181.50 rupees). Stock is below the fixed minimum threshold!
#
# Product P10006 in Warehouse WIND07:
#   Current Stock: 15
#   Forecasted Demand: 47
#   Diff (Current - Forecast): -32.00
#   External Ordering Cost: 2292.0
#   Recommendation: Needs to order 32 units externally (Cost: 2292.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10007 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: -34
#   Diff (Current - Forecast): 46.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 46 units; consider transfer. Stock is below the fixed minimum threshold!
#
# Product P10008 in Warehouse WIND07:
#   Current Stock: 27
#   Forecasted Demand: 33
#   Diff (Current - Forecast): -6.00
#   External Ordering Cost: 2071.0
#   Recommendation: Needs to order 6 units externally (Cost: 2071.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10009 in Warehouse WIND07:
#   Current Stock: 42
#   Forecasted Demand: 47
#   Diff (Current - Forecast): -5.00
#   External Ordering Cost: 2062.5
#   Recommendation: Needs to order 5 units externally (Cost: 2062.50 rupees). Stock is below the fixed minimum threshold!
#
# Product P10010 in Warehouse WIND07:
#   Current Stock: 53
#   Forecasted Demand: 64
#   Diff (Current - Forecast): -11.00
#   External Ordering Cost: 2113.5
#   Recommendation: Needs to order 11 units externally (Cost: 2113.50 rupees). Stock is below the fixed minimum threshold!
#
# Cross-Warehouse Transfer Recommendations:
# Product P10001: Order 7 units externally for Warehouse WIND01 (External Cost: 2079.50 rupees).
# Product P10001: Order 17 units externally for Warehouse WIND02 (External Cost: 2164.50 rupees).
# Product P10001: Order 13 units externally for Warehouse WIND03 (External Cost: 2130.50 rupees).
# Product P10001: Order 37 units externally for Warehouse WIND04 (External Cost: 2334.50 rupees).
# Product P10001: Order 37 units externally for Warehouse WIND04 (External Cost: 2334.50 rupees).
# Product P10001: Transfer 2 units from Warehouse WIND07 to Warehouse WIND04 (Transfer Cost: 1800.00 rupees).
# Product P10002: Order 24 units externally for Warehouse WIND01 (External Cost: 2224.00 rupees).
# Product P10002: Order 58 units externally for Warehouse WIND02 (External Cost: 2513.00 rupees).
# Product P10002: Order 58 units externally for Warehouse WIND02 (External Cost: 2513.00 rupees).
# Product P10002: Order 58 units externally for Warehouse WIND02 (External Cost: 2513.00 rupees).
# Product P10003: Order 33 units externally for Warehouse WIND01 (External Cost: 2300.50 rupees).
# Product P10003: Order 33 units externally for Warehouse WIND01 (External Cost: 2300.50 rupees).
# Product P10004: Order 32 units externally for Warehouse WIND01 (External Cost: 2292.00 rupees).
# Product P10004: Order 32 units externally for Warehouse WIND01 (External Cost: 2292.00 rupees).
# Product P10005: Order 6 units externally for Warehouse WIND04 (External Cost: 2071.00 rupees).
# Product P10005: Order 57 units externally for Warehouse WIND05 (External Cost: 2504.50 rupees).
# Product P10005: Order 57 units externally for Warehouse WIND05 (External Cost: 2504.50 rupees).
# Product P10005: Order 57 units externally for Warehouse WIND05 (External Cost: 2504.50 rupees).
# Product P10006: Order 33 units externally for Warehouse WIND01 (External Cost: 2300.50 rupees).
# Product P10006: Order 7 units externally for Warehouse WIND03 (External Cost: 2079.50 rupees).
# Product P10006: Order 34 units externally for Warehouse WIND04 (External Cost: 2309.00 rupees).
# Product P10006: Order 12 units externally for Warehouse WIND05 (External Cost: 2122.00 rupees).
# Product P10007: Order 44 units externally for Warehouse WIND01 (External Cost: 2394.00 rupees).
# Product P10007: Order 30 units externally for Warehouse WIND02 (External Cost: 2275.00 rupees).
# Product P10008: Order 40 units externally for Warehouse WIND03 (External Cost: 2360.00 rupees).
# Product P10008: Order 19 units externally for Warehouse WIND04 (External Cost: 2181.50 rupees).
# Product P10008: Order 30 units externally for Warehouse WIND06 (External Cost: 2275.00 rupees).
# Product P10008: Order 30 units externally for Warehouse WIND06 (External Cost: 2275.00 rupees).
# Product P10008: Order 30 units externally for Warehouse WIND06 (External Cost: 2275.00 rupees).
# Product P10008: Order 6 units externally for Warehouse WIND07 (External Cost: 2071.00 rupees).
# Product P10009: Transfer 1 units from Warehouse WIND01 to Warehouse WIND04 (Transfer Cost: 1200.00 rupees).
# Product P10009: Order 2 units externally for Warehouse WIND04 (External Cost: 2037.00 rupees).
# Product P10009: Order 18 units externally for Warehouse WIND05 (External Cost: 2173.00 rupees).
# Product P10009: Order 18 units externally for Warehouse WIND05 (External Cost: 2173.00 rupees).
# Product P10009: Order 5 units externally for Warehouse WIND07 (External Cost: 2062.50 rupees).
# Product P10010: Order 18 units externally for Warehouse WIND01 (External Cost: 2173.00 rupees).
# Product P10010: Order 18 units externally for Warehouse WIND01 (External Cost: 2173.00 rupees).
# Product P10010: Transfer 1 units from Warehouse WIND06 to Warehouse WIND02 (Transfer Cost: 1500.00 rupees).

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
import datetime

# -------------------------
# MongoDB Connection using your provided connection string
# -------------------------
connection_string = "mongodb+srv://himavarshithreddy:invenx@invenx.kxiph.mongodb.net/?retryWrites=true&w=majority&appName=InvenX"
client = MongoClient(connection_string)
db = client["InvenX"]

# -------------------------
# Retrieve Inventory Data
# -------------------------
inventory_collection = db["inventory"]
inventory_docs = list(inventory_collection.find({}, {
    "_id": 0,
    "warehouse_id": 1,
    "product_id": 1,
    "current_stock": 1,
    "min_stock": 1,
    "max_stock": 1,
    "last_updated": 1,
    "forecast_value": 1
}))
inventory_df = pd.DataFrame(inventory_docs)
print("Inventory Data:")
print(inventory_df)

# -------------------------
# Retrieve Warehouses Data (for ordering_cost)
# -------------------------
warehouses_collection = db["warehouses"]
warehouse_docs = list(warehouses_collection.find({}, {
    "_id": 1,           # Using _id as the warehouse identifier
    "ordering_cost": 1
}))
warehouses_df = pd.DataFrame(warehouse_docs)
if not warehouses_df.empty:
    if "_id" in warehouses_df.columns:
        warehouses_df = warehouses_df.rename(columns={"_id": "warehouse_id"})
else:
    print("Warning: Warehouses Data is empty; using default ordering cost.")

print("\nWarehouses Data:")
print(warehouses_df)

# -------------------------
# Retrieve Warehouse Transfers Data (for transfer cost)
# -------------------------
warehouse_transfers_collection = db["warehouse_transfers"]
warehouse_transfers_docs = list(warehouse_transfers_collection.find({}, {
    "_id": 0,
    "source_warehouse_id": 1,
    "destination_warehouse_id": 1,
    "transfer_cost": 1,
    "currency": 1,
    "estimated_transfer_time": 1
}))
warehouse_transfers_df = pd.DataFrame(warehouse_transfers_docs)
print("\nWarehouse Transfers Data:")
print(warehouse_transfers_df)

# -------------------------
# Merge Inventory with Warehouses Data to Include Ordering Cost
# -------------------------
default_ordering_cost = 2000.0  # Default ordering cost if warehouse data is missing
if warehouses_df.empty:
    inventory_df["ordering_cost"] = default_ordering_cost
else:
    inventory_df = pd.merge(inventory_df, warehouses_df[["warehouse_id", "ordering_cost"]],
                              on="warehouse_id", how="left")
    inventory_df["ordering_cost"] = inventory_df["ordering_cost"].fillna(default_ordering_cost)

print("\nInventory Data after merging ordering cost:")
print(inventory_df)

# -------------------------
# Configuration: Cost Parameters
# -------------------------
per_unit_order_cost = 5.0         # Cost per unit ordered (rupees)
external_transport_cost = 20.0    # External transportation cost (rupees)
holding_cost_per_unit_day = 0.5   # Holding cost per unit per day (rupees)
forecast_period_days = 7          # Forecast period (in days)
default_per_unit_transfer_cost = 15.0  # Default per-unit transfer cost if no record is found
safety_factor = 0.2               # 20% safety factor

# -------------------------
# Step 1: Compute Dynamic Safety Stock and Difference
# -------------------------
# Calculate dynamic safety stock: (for clarity, we include it in the output)
inventory_df['dynamic_min_stock'] = (inventory_df['forecast_value'] * (1 + safety_factor)).round()
# Compute the difference: current_stock - forecast_value (we use forecast_value as our target)
inventory_df['diff'] = inventory_df['current_stock'] - inventory_df['forecast_value']

# -------------------------
# Step 2: Generate Individual Recommendations (Before Transfers)
# -------------------------
individual_recommendations = {}

for idx, row in inventory_df.iterrows():
    prod = row["product_id"]
    ware = row["warehouse_id"]
    current_stock = row["current_stock"]
    forecast_value = row["forecast_value"]
    dynamic_min = row["dynamic_min_stock"]
    diff = row["diff"]
    min_stock = row["min_stock"]
    max_stock = row["max_stock"]
    order_cost = row["ordering_cost"]

    rec_message = ""
    external_order_cost = None

    # If current stock is less than forecasted demand, compute the deficit.
    if current_stock < forecast_value:
        deficit = forecast_value - current_stock
        external_order_cost = (order_cost +
                               (per_unit_order_cost * deficit) +
                               external_transport_cost +
                               (holding_cost_per_unit_day * forecast_period_days * deficit))
        rec_message += f"Needs to order {deficit:.0f} units externally (Cost: {external_order_cost:.2f} rupees). "
    else:
        surplus = current_stock - forecast_value
        rec_message += f"Has excess of {surplus:.0f} units; potential for internal transfer. "

    # Fixed threshold alerts:
    if current_stock < min_stock:
        rec_message += "Stock is below the fixed minimum threshold! "
    if current_stock > max_stock:
        rec_message += "Stock exceeds the maximum limit; consider reducing inventory. "

    individual_recommendations[(prod, ware)] = {
        "current_stock": current_stock,
        "forecast_value": forecast_value,
        "dynamic_min_stock": dynamic_min,
        "diff": diff,
        "external_order_cost": external_order_cost,
        "recommendation": rec_message
    }

print("\nIndividual Inventory Recommendations:")
for (prod, ware), rec in individual_recommendations.items():
    print(f"\nProduct {prod} in Warehouse {ware}:")
    print(f"  Current Stock: {rec['current_stock']}")
    print(f"  Forecasted Demand: {rec['forecast_value']}")
    print(f"  Dynamic Safety Stock: {rec['dynamic_min_stock']:.2f}")
    print(f"  Diff (Current - Forecast): {rec['diff']:.2f}")
    print(f"  External Ordering Cost: {rec['external_order_cost']}")
    print(f"  Recommendation: {rec['recommendation']}")

# -------------------------
# Step 2.5: Prepare Data for Cross-Warehouse Analysis
# -------------------------
# For each product, group the inventory data across warehouses
# and calculate the surplus/deficit for internal transfers.
# Here we use diff = current_stock - forecast_value.
# A positive diff means surplus; negative means deficit.
transfer_recommendations = {}

for prod, group in inventory_df.groupby("product_id"):
    surplus_list = []  # List of tuples: (warehouse_id, surplus_amount)
    deficit_list = []  # List of tuples: (warehouse_id, deficit_amount)

    for idx, row in group.iterrows():
        wh = row["warehouse_id"]
        diff = row["current_stock"] - row["forecast_value"]
        if diff > 0:
            surplus_list.append((wh, diff))
        elif diff < 0:
            deficit_list.append((wh, -diff))  # store as positive deficit amount

    # -------------------------
    # Step 3: Match Surpluses to Deficits for Internal Transfers
    # -------------------------
    # For each deficit warehouse, attempt to cover the deficit from warehouses with surplus.
    for d_idx, (def_wh, def_qty) in enumerate(deficit_list):
        for s_idx, (surp_wh, surp_qty) in enumerate(surplus_list):
            if surp_qty > 0 and def_qty > 0:
                transfer_qty = min(surp_qty, def_qty)
                # Look up transfer cost for this pair in warehouse_transfers_df.
                transfer_record = warehouse_transfers_df[
                    (warehouse_transfers_df["source_warehouse_id"] == surp_wh) &
                    (warehouse_transfers_df["destination_warehouse_id"] == def_wh)
                ]
                if not transfer_record.empty:
                    transfer_cost = float(transfer_record.iloc[0]["transfer_cost"]) * transfer_qty
                else:
                    transfer_cost = default_per_unit_transfer_cost * transfer_qty

                # Get external ordering cost for the deficit warehouse (if available)
                ext_order_cost = individual_recommendations.get((prod, def_wh), {}).get("external_order_cost", np.inf)

                # Decide: if transfer cost is lower than external ordering cost, recommend transfer.
                if transfer_cost < ext_order_cost:
                    rec_text = f"Transfer {transfer_qty:.0f} units from Warehouse {surp_wh} to Warehouse {def_wh} (Transfer Cost: {transfer_cost:.2f} rupees)."
                else:
                    rec_text = f"Order {def_qty:.0f} units externally for Warehouse {def_wh} (External Cost: {ext_order_cost:.2f} rupees)."

                key = (prod, surp_wh, def_wh)
                transfer_recommendations[key] = {
                    "transfer_qty": transfer_qty,
                    "transfer_cost": transfer_cost,
                    "external_order_cost": ext_order_cost,
                    "recommendation": rec_text
                }

                # Update the surplus and deficit amounts.
                surplus_list[s_idx] = (surp_wh, surp_qty - transfer_qty)
                deficit_list[d_idx] = (def_wh, def_qty - transfer_qty)
                if deficit_list[d_idx][1] == 0:
                    break

print("\nCross-Warehouse Transfer Recommendations:")
if transfer_recommendations:
    for (prod, from_wh, to_wh), info in transfer_recommendations.items():
        print(f"Product {prod}: {info['recommendation']}")
else:
    print("No internal transfer recommendations available.")
# Out:
# Inventory Data:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56          9        100
# 1        WIND01     P10002             43         10        100
# 2        WIND01     P10003             32         15        100
# 3        WIND01     P10004             29          9        100
# 4        WIND01     P10005             59          7        100
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15         14        100
# 66       WIND07     P10007             12         12        100
# 67       WIND07     P10008             27         15        100
# 68       WIND07     P10009             42         11        100
# 69       WIND07     P10010             53         13        100
#
#             last_updated  forecast_value
# 0   2025-02-10T10:00:00Z              63
# 1   2025-02-10T10:00:00Z              67
# 2   2025-02-10T10:00:00Z              65
# 3   2025-02-10T10:00:00Z              61
# 4   2025-02-10T10:00:00Z              26
# ..                   ...             ...
# 65  2025-02-10T10:00:00Z              47
# 66  2025-02-10T10:00:00Z             -34
# 67  2025-02-10T10:00:00Z              33
# 68  2025-02-10T10:00:00Z              47
# 69  2025-02-10T10:00:00Z              64
#
# [70 rows x 7 columns]
# Warning: Warehouses Data is empty; using default ordering cost.
#
# Warehouses Data:
# Empty DataFrame
# Columns: []
# Index: []
#
# Warehouse Transfers Data:
#    source_warehouse_id destination_warehouse_id  transfer_cost currency  \
# 0               WIND01                   WIND02           2000      INR
# 1               WIND01                   WIND03           1500      INR
# 2               WIND01                   WIND04           1200      INR
# 3               WIND01                   WIND05           1300      INR
# 4               WIND01                   WIND06           1800      INR
# 5               WIND01                   WIND07            500      INR
# 6               WIND02                   WIND01           2000      INR
# 7               WIND02                   WIND03           2200      INR
# 8               WIND02                   WIND04           2000      INR
# 9               WIND02                   WIND05           2100      INR
# 10              WIND02                   WIND06           1500      INR
# 11              WIND02                   WIND07           1900      INR
# 12              WIND03                   WIND01           1500      INR
# 13              WIND03                   WIND02           2200      INR
# 14              WIND03                   WIND04            800      INR
# 15              WIND03                   WIND05            900      INR
# 16              WIND03                   WIND06           1700      INR
# 17              WIND03                   WIND07           1000      INR
# 18              WIND04                   WIND01           1200      INR
# 19              WIND04                   WIND02           2000      INR
# 20              WIND04                   WIND03            800      INR
# 21              WIND04                   WIND05            700      INR
# 22              WIND04                   WIND06           1600      INR
# 23              WIND04                   WIND07            900      INR
# 24              WIND05                   WIND01           1300      INR
# 25              WIND05                   WIND02           2100      INR
# 26              WIND05                   WIND03            900      INR
# 27              WIND05                   WIND04            700      INR
# 28              WIND05                   WIND06           1800      INR
# 29              WIND05                   WIND07           1100      INR
# 30              WIND06                   WIND01           1800      INR
# 31              WIND06                   WIND02           1500      INR
# 32              WIND06                   WIND03           1700      INR
# 33              WIND06                   WIND04           1600      INR
# 34              WIND06                   WIND05           1800      INR
# 35              WIND06                   WIND07           1900      INR
# 36              WIND07                   WIND01            500      INR
# 37              WIND07                   WIND02           1900      INR
# 38              WIND07                   WIND03           1000      INR
# 39              WIND07                   WIND04            900      INR
# 40              WIND07                   WIND05           1100      INR
# 41              WIND07                   WIND06           1900      INR
#
#    estimated_transfer_time
# 0                   2 days
# 1                   2 days
# 2                 1.5 days
# 3                   2 days
# 4                   2 days
# 5                    1 day
# 6                   2 days
# 7                   2 days
# 8                   2 days
# 9                   2 days
# 10                1.5 days
# 11                  2 days
# 12                  2 days
# 13                  2 days
# 14                   1 day
# 15                   1 day
# 16                  2 days
# 17                   1 day
# 18                1.5 days
# 19                  2 days
# 20                   1 day
# 21                   1 day
# 22                  2 days
# 23                   1 day
# 24                  2 days
# 25                  2 days
# 26                   1 day
# 27                   1 day
# 28                  2 days
# 29                1.5 days
# 30                  2 days
# 31                1.5 days
# 32                  2 days
# 33                  2 days
# 34                  2 days
# 35                  2 days
# 36                   1 day
# 37                  2 days
# 38                   1 day
# 39                   1 day
# 40                1.5 days
# 41                  2 days
#
# Inventory Data after merging ordering cost:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56          9        100
# 1        WIND01     P10002             43         10        100
# 2        WIND01     P10003             32         15        100
# 3        WIND01     P10004             29          9        100
# 4        WIND01     P10005             59          7        100
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15         14        100
# 66       WIND07     P10007             12         12        100
# 67       WIND07     P10008             27         15        100
# 68       WIND07     P10009             42         11        100
# 69       WIND07     P10010             53         13        100
#
#             last_updated  forecast_value  ordering_cost
# 0   2025-02-10T10:00:00Z              63         2000.0
# 1   2025-02-10T10:00:00Z              67         2000.0
# 2   2025-02-10T10:00:00Z              65         2000.0
# 3   2025-02-10T10:00:00Z              61         2000.0
# 4   2025-02-10T10:00:00Z              26         2000.0
# ..                   ...             ...            ...
# 65  2025-02-10T10:00:00Z              47         2000.0
# 66  2025-02-10T10:00:00Z             -34         2000.0
# 67  2025-02-10T10:00:00Z              33         2000.0
# 68  2025-02-10T10:00:00Z              47         2000.0
# 69  2025-02-10T10:00:00Z              64         2000.0
#
# [70 rows x 8 columns]
#
# Individual Inventory Recommendations:
#
# Product P10001 in Warehouse WIND01:
#   Current Stock: 56
#   Forecasted Demand: 63
#   Dynamic Safety Stock: 76.00
#   Diff (Current - Forecast): -7.00
#   External Ordering Cost: 2079.5
#   Recommendation: Needs to order 7 units externally (Cost: 2079.50 rupees).
#
# Product P10002 in Warehouse WIND01:
#   Current Stock: 43
#   Forecasted Demand: 67
#   Dynamic Safety Stock: 80.00
#   Diff (Current - Forecast): -24.00
#   External Ordering Cost: 2224.0
#   Recommendation: Needs to order 24 units externally (Cost: 2224.00 rupees).
#
# Product P10003 in Warehouse WIND01:
#   Current Stock: 32
#   Forecasted Demand: 65
#   Dynamic Safety Stock: 78.00
#   Diff (Current - Forecast): -33.00
#   External Ordering Cost: 2300.5
#   Recommendation: Needs to order 33 units externally (Cost: 2300.50 rupees).
#
# Product P10004 in Warehouse WIND01:
#   Current Stock: 29
#   Forecasted Demand: 61
#   Dynamic Safety Stock: 73.00
#   Diff (Current - Forecast): -32.00
#   External Ordering Cost: 2292.0
#   Recommendation: Needs to order 32 units externally (Cost: 2292.00 rupees).
#
# Product P10005 in Warehouse WIND01:
#   Current Stock: 59
#   Forecasted Demand: 26
#   Dynamic Safety Stock: 31.00
#   Diff (Current - Forecast): 33.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 33 units; potential for internal transfer.
#
# Product P10006 in Warehouse WIND01:
#   Current Stock: 47
#   Forecasted Demand: 80
#   Dynamic Safety Stock: 96.00
#   Diff (Current - Forecast): -33.00
#   External Ordering Cost: 2300.5
#   Recommendation: Needs to order 33 units externally (Cost: 2300.50 rupees).
#
# Product P10007 in Warehouse WIND01:
#   Current Stock: 33
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.00
#   Diff (Current - Forecast): -44.00
#   External Ordering Cost: 2394.0
#   Recommendation: Needs to order 44 units externally (Cost: 2394.00 rupees).
#
# Product P10008 in Warehouse WIND01:
#   Current Stock: 87
#   Forecasted Demand: 23
#   Dynamic Safety Stock: 28.00
#   Diff (Current - Forecast): 64.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 64 units; potential for internal transfer.
#
# Product P10009 in Warehouse WIND01:
#   Current Stock: 99
#   Forecasted Demand: 98
#   Dynamic Safety Stock: 118.00
#   Diff (Current - Forecast): 1.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 1 units; potential for internal transfer.
#
# Product P10010 in Warehouse WIND01:
#   Current Stock: 25
#   Forecasted Demand: 43
#   Dynamic Safety Stock: 52.00
#   Diff (Current - Forecast): -18.00
#   External Ordering Cost: 2173.0
#   Recommendation: Needs to order 18 units externally (Cost: 2173.00 rupees).
#
# Product P10001 in Warehouse WIND02:
#   Current Stock: 40
#   Forecasted Demand: 57
#   Dynamic Safety Stock: 68.00
#   Diff (Current - Forecast): -17.00
#   External Ordering Cost: 2164.5
#   Recommendation: Needs to order 17 units externally (Cost: 2164.50 rupees).
#
# Product P10002 in Warehouse WIND02:
#   Current Stock: 10
#   Forecasted Demand: 68
#   Dynamic Safety Stock: 82.00
#   Diff (Current - Forecast): -58.00
#   External Ordering Cost: 2513.0
#   Recommendation: Needs to order 58 units externally (Cost: 2513.00 rupees).
#
# Product P10003 in Warehouse WIND02:
#   Current Stock: 69
#   Forecasted Demand: 74
#   Dynamic Safety Stock: 89.00
#   Diff (Current - Forecast): -5.00
#   External Ordering Cost: 2062.5
#   Recommendation: Needs to order 5 units externally (Cost: 2062.50 rupees).
#
# Product P10004 in Warehouse WIND02:
#   Current Stock: 73
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 59.00
#   Diff (Current - Forecast): 24.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 24 units; potential for internal transfer.
#
# Product P10005 in Warehouse WIND02:
#   Current Stock: 84
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 58.00
#   Diff (Current - Forecast): 36.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 36 units; potential for internal transfer.
#
# Product P10006 in Warehouse WIND02:
#   Current Stock: 94
#   Forecasted Demand: 17
#   Dynamic Safety Stock: 20.00
#   Diff (Current - Forecast): 77.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 77 units; potential for internal transfer.
#
# Product P10007 in Warehouse WIND02:
#   Current Stock: 19
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 59.00
#   Diff (Current - Forecast): -30.00
#   External Ordering Cost: 2275.0
#   Recommendation: Needs to order 30 units externally (Cost: 2275.00 rupees).
#
# Product P10008 in Warehouse WIND02:
#   Current Stock: 77
#   Forecasted Demand: 52
#   Dynamic Safety Stock: 62.00
#   Diff (Current - Forecast): 25.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 25 units; potential for internal transfer.
#
# Product P10009 in Warehouse WIND02:
#   Current Stock: 63
#   Forecasted Demand: 45
#   Dynamic Safety Stock: 54.00
#   Diff (Current - Forecast): 18.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 18 units; potential for internal transfer.
#
# Product P10010 in Warehouse WIND02:
#   Current Stock: 43
#   Forecasted Demand: 118
#   Dynamic Safety Stock: 142.00
#   Diff (Current - Forecast): -75.00
#   External Ordering Cost: 2657.5
#   Recommendation: Needs to order 75 units externally (Cost: 2657.50 rupees).
#
# Product P10001 in Warehouse WIND03:
#   Current Stock: 36
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 59.00
#   Diff (Current - Forecast): -13.00
#   External Ordering Cost: 2130.5
#   Recommendation: Needs to order 13 units externally (Cost: 2130.50 rupees).
#
# Product P10002 in Warehouse WIND03:
#   Current Stock: 91
#   Forecasted Demand: 53
#   Dynamic Safety Stock: 64.00
#   Diff (Current - Forecast): 38.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 38 units; potential for internal transfer.
#
# Product P10003 in Warehouse WIND03:
#   Current Stock: 45
#   Forecasted Demand: 76
#   Dynamic Safety Stock: 91.00
#   Diff (Current - Forecast): -31.00
#   External Ordering Cost: 2283.5
#   Recommendation: Needs to order 31 units externally (Cost: 2283.50 rupees).
#
# Product P10004 in Warehouse WIND03:
#   Current Stock: 81
#   Forecasted Demand: 58
#   Dynamic Safety Stock: 70.00
#   Diff (Current - Forecast): 23.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 23 units; potential for internal transfer.
#
# Product P10005 in Warehouse WIND03:
#   Current Stock: 77
#   Forecasted Demand: 65
#   Dynamic Safety Stock: 78.00
#   Diff (Current - Forecast): 12.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 12 units; potential for internal transfer.
#
# Product P10006 in Warehouse WIND03:
#   Current Stock: 54
#   Forecasted Demand: 61
#   Dynamic Safety Stock: 73.00
#   Diff (Current - Forecast): -7.00
#   External Ordering Cost: 2079.5
#   Recommendation: Needs to order 7 units externally (Cost: 2079.50 rupees).
#
# Product P10007 in Warehouse WIND03:
#   Current Stock: 35
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.00
#   Diff (Current - Forecast): -42.00
#   External Ordering Cost: 2377.0
#   Recommendation: Needs to order 42 units externally (Cost: 2377.00 rupees).
#
# Product P10008 in Warehouse WIND03:
#   Current Stock: 37
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.00
#   Diff (Current - Forecast): -40.00
#   External Ordering Cost: 2360.0
#   Recommendation: Needs to order 40 units externally (Cost: 2360.00 rupees).
#
# Product P10009 in Warehouse WIND03:
#   Current Stock: 73
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 58.00
#   Diff (Current - Forecast): 25.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 25 units; potential for internal transfer.
#
# Product P10010 in Warehouse WIND03:
#   Current Stock: 28
#   Forecasted Demand: 112
#   Dynamic Safety Stock: 134.00
#   Diff (Current - Forecast): -84.00
#   External Ordering Cost: 2734.0
#   Recommendation: Needs to order 84 units externally (Cost: 2734.00 rupees).
#
# Product P10001 in Warehouse WIND04:
#   Current Stock: 29
#   Forecasted Demand: 66
#   Dynamic Safety Stock: 79.00
#   Diff (Current - Forecast): -37.00
#   External Ordering Cost: 2334.5
#   Recommendation: Needs to order 37 units externally (Cost: 2334.50 rupees).
#
# Product P10002 in Warehouse WIND04:
#   Current Stock: 37
#   Forecasted Demand: 33
#   Dynamic Safety Stock: 40.00
#   Diff (Current - Forecast): 4.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 4 units; potential for internal transfer.
#
# Product P10003 in Warehouse WIND04:
#   Current Stock: 66
#   Forecasted Demand: 56
#   Dynamic Safety Stock: 67.00
#   Diff (Current - Forecast): 10.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 10 units; potential for internal transfer.
#
# Product P10004 in Warehouse WIND04:
#   Current Stock: 40
#   Forecasted Demand: 78
#   Dynamic Safety Stock: 94.00
#   Diff (Current - Forecast): -38.00
#   External Ordering Cost: 2343.0
#   Recommendation: Needs to order 38 units externally (Cost: 2343.00 rupees).
#
# Product P10005 in Warehouse WIND04:
#   Current Stock: 39
#   Forecasted Demand: 45
#   Dynamic Safety Stock: 54.00
#   Diff (Current - Forecast): -6.00
#   External Ordering Cost: 2071.0
#   Recommendation: Needs to order 6 units externally (Cost: 2071.00 rupees).
#
# Product P10006 in Warehouse WIND04:
#   Current Stock: 54
#   Forecasted Demand: 88
#   Dynamic Safety Stock: 106.00
#   Diff (Current - Forecast): -34.00
#   External Ordering Cost: 2309.0
#   Recommendation: Needs to order 34 units externally (Cost: 2309.00 rupees).
#
# Product P10007 in Warehouse WIND04:
#   Current Stock: 77
#   Forecasted Demand: 87
#   Dynamic Safety Stock: 104.00
#   Diff (Current - Forecast): -10.00
#   External Ordering Cost: 2105.0
#   Recommendation: Needs to order 10 units externally (Cost: 2105.00 rupees).
#
# Product P10008 in Warehouse WIND04:
#   Current Stock: 49
#   Forecasted Demand: 68
#   Dynamic Safety Stock: 82.00
#   Diff (Current - Forecast): -19.00
#   External Ordering Cost: 2181.5
#   Recommendation: Needs to order 19 units externally (Cost: 2181.50 rupees).
#
# Product P10009 in Warehouse WIND04:
#   Current Stock: 75
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.00
#   Diff (Current - Forecast): -2.00
#   External Ordering Cost: 2037.0
#   Recommendation: Needs to order 2 units externally (Cost: 2037.00 rupees).
#
# Product P10010 in Warehouse WIND04:
#   Current Stock: 35
#   Forecasted Demand: 53
#   Dynamic Safety Stock: 64.00
#   Diff (Current - Forecast): -18.00
#   External Ordering Cost: 2173.0
#   Recommendation: Needs to order 18 units externally (Cost: 2173.00 rupees).
#
# Product P10001 in Warehouse WIND05:
#   Current Stock: 88
#   Forecasted Demand: 47
#   Dynamic Safety Stock: 56.00
#   Diff (Current - Forecast): 41.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 41 units; potential for internal transfer.
#
# Product P10002 in Warehouse WIND05:
#   Current Stock: 72
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 59.00
#   Diff (Current - Forecast): 23.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 23 units; potential for internal transfer.
#
# Product P10003 in Warehouse WIND05:
#   Current Stock: 66
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 58.00
#   Diff (Current - Forecast): 18.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 18 units; potential for internal transfer.
#
# Product P10004 in Warehouse WIND05:
#   Current Stock: 51
#   Forecasted Demand: 84
#   Dynamic Safety Stock: 101.00
#   Diff (Current - Forecast): -33.00
#   External Ordering Cost: 2300.5
#   Recommendation: Needs to order 33 units externally (Cost: 2300.50 rupees).
#
# Product P10005 in Warehouse WIND05:
#   Current Stock: 25
#   Forecasted Demand: 82
#   Dynamic Safety Stock: 98.00
#   Diff (Current - Forecast): -57.00
#   External Ordering Cost: 2504.5
#   Recommendation: Needs to order 57 units externally (Cost: 2504.50 rupees).
#
# Product P10006 in Warehouse WIND05:
#   Current Stock: 31
#   Forecasted Demand: 43
#   Dynamic Safety Stock: 52.00
#   Diff (Current - Forecast): -12.00
#   External Ordering Cost: 2122.0
#   Recommendation: Needs to order 12 units externally (Cost: 2122.00 rupees).
#
# Product P10007 in Warehouse WIND05:
#   Current Stock: 47
#   Forecasted Demand: 70
#   Dynamic Safety Stock: 84.00
#   Diff (Current - Forecast): -23.00
#   External Ordering Cost: 2215.5
#   Recommendation: Needs to order 23 units externally (Cost: 2215.50 rupees).
#
# Product P10008 in Warehouse WIND05:
#   Current Stock: 52
#   Forecasted Demand: 5
#   Dynamic Safety Stock: 6.00
#   Diff (Current - Forecast): 47.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 47 units; potential for internal transfer.
#
# Product P10009 in Warehouse WIND05:
#   Current Stock: 33
#   Forecasted Demand: 51
#   Dynamic Safety Stock: 61.00
#   Diff (Current - Forecast): -18.00
#   External Ordering Cost: 2173.0
#   Recommendation: Needs to order 18 units externally (Cost: 2173.00 rupees).
#
# Product P10010 in Warehouse WIND05:
#   Current Stock: 58
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 58.00
#   Diff (Current - Forecast): 10.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 10 units; potential for internal transfer.
#
# Product P10001 in Warehouse WIND06:
#   Current Stock: 80
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.00
#   Diff (Current - Forecast): 3.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 3 units; potential for internal transfer.
#
# Product P10002 in Warehouse WIND06:
#   Current Stock: 63
#   Forecasted Demand: 74
#   Dynamic Safety Stock: 89.00
#   Diff (Current - Forecast): -11.00
#   External Ordering Cost: 2113.5
#   Recommendation: Needs to order 11 units externally (Cost: 2113.50 rupees).
#
# Product P10003 in Warehouse WIND06:
#   Current Stock: 38
#   Forecasted Demand: 89
#   Dynamic Safety Stock: 107.00
#   Diff (Current - Forecast): -51.00
#   External Ordering Cost: 2453.5
#   Recommendation: Needs to order 51 units externally (Cost: 2453.50 rupees).
#
# Product P10004 in Warehouse WIND06:
#   Current Stock: 26
#   Forecasted Demand: 90
#   Dynamic Safety Stock: 108.00
#   Diff (Current - Forecast): -64.00
#   External Ordering Cost: 2564.0
#   Recommendation: Needs to order 64 units externally (Cost: 2564.00 rupees).
#
# Product P10005 in Warehouse WIND06:
#   Current Stock: 31
#   Forecasted Demand: 57
#   Dynamic Safety Stock: 68.00
#   Diff (Current - Forecast): -26.00
#   External Ordering Cost: 2241.0
#   Recommendation: Needs to order 26 units externally (Cost: 2241.00 rupees).
#
# Product P10006 in Warehouse WIND06:
#   Current Stock: 47
#   Forecasted Demand: 63
#   Dynamic Safety Stock: 76.00
#   Diff (Current - Forecast): -16.00
#   External Ordering Cost: 2156.0
#   Recommendation: Needs to order 16 units externally (Cost: 2156.00 rupees).
#
# Product P10007 in Warehouse WIND06:
#   Current Stock: 10
#   Forecasted Demand: 27
#   Dynamic Safety Stock: 32.00
#   Diff (Current - Forecast): -17.00
#   External Ordering Cost: 2164.5
#   Recommendation: Needs to order 17 units externally (Cost: 2164.50 rupees).
#
# Product P10008 in Warehouse WIND06:
#   Current Stock: 45
#   Forecasted Demand: 75
#   Dynamic Safety Stock: 90.00
#   Diff (Current - Forecast): -30.00
#   External Ordering Cost: 2275.0
#   Recommendation: Needs to order 30 units externally (Cost: 2275.00 rupees).
#
# Product P10009 in Warehouse WIND06:
#   Current Stock: 49
#   Forecasted Demand: 22
#   Dynamic Safety Stock: 26.00
#   Diff (Current - Forecast): 27.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 27 units; potential for internal transfer.
#
# Product P10010 in Warehouse WIND06:
#   Current Stock: 62
#   Forecasted Demand: 43
#   Dynamic Safety Stock: 52.00
#   Diff (Current - Forecast): 19.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 19 units; potential for internal transfer.
#
# Product P10001 in Warehouse WIND07:
#   Current Stock: 32
#   Forecasted Demand: 30
#   Dynamic Safety Stock: 36.00
#   Diff (Current - Forecast): 2.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 2 units; potential for internal transfer.
#
# Product P10002 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: 68
#   Dynamic Safety Stock: 82.00
#   Diff (Current - Forecast): -56.00
#   External Ordering Cost: 2496.0
#   Recommendation: Needs to order 56 units externally (Cost: 2496.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10003 in Warehouse WIND07:
#   Current Stock: 23
#   Forecasted Demand: 62
#   Dynamic Safety Stock: 74.00
#   Diff (Current - Forecast): -39.00
#   External Ordering Cost: 2351.5
#   Recommendation: Needs to order 39 units externally (Cost: 2351.50 rupees).
#
# Product P10004 in Warehouse WIND07:
#   Current Stock: 43
#   Forecasted Demand: 69
#   Dynamic Safety Stock: 83.00
#   Diff (Current - Forecast): -26.00
#   External Ordering Cost: 2241.0
#   Recommendation: Needs to order 26 units externally (Cost: 2241.00 rupees).
#
# Product P10005 in Warehouse WIND07:
#   Current Stock: 20
#   Forecasted Demand: 39
#   Dynamic Safety Stock: 47.00
#   Diff (Current - Forecast): -19.00
#   External Ordering Cost: 2181.5
#   Recommendation: Needs to order 19 units externally (Cost: 2181.50 rupees).
#
# Product P10006 in Warehouse WIND07:
#   Current Stock: 15
#   Forecasted Demand: 47
#   Dynamic Safety Stock: 56.00
#   Diff (Current - Forecast): -32.00
#   External Ordering Cost: 2292.0
#   Recommendation: Needs to order 32 units externally (Cost: 2292.00 rupees).
#
# Product P10007 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: -34
#   Dynamic Safety Stock: -41.00
#   Diff (Current - Forecast): 46.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 46 units; potential for internal transfer.
#
# Product P10008 in Warehouse WIND07:
#   Current Stock: 27
#   Forecasted Demand: 33
#   Dynamic Safety Stock: 40.00
#   Diff (Current - Forecast): -6.00
#   External Ordering Cost: 2071.0
#   Recommendation: Needs to order 6 units externally (Cost: 2071.00 rupees).
#
# Product P10009 in Warehouse WIND07:
#   Current Stock: 42
#   Forecasted Demand: 47
#   Dynamic Safety Stock: 56.00
#   Diff (Current - Forecast): -5.00
#   External Ordering Cost: 2062.5
#   Recommendation: Needs to order 5 units externally (Cost: 2062.50 rupees).
#
# Product P10010 in Warehouse WIND07:
#   Current Stock: 53
#   Forecasted Demand: 64
#   Dynamic Safety Stock: 77.00
#   Diff (Current - Forecast): -11.00
#   External Ordering Cost: 2113.5
#   Recommendation: Needs to order 11 units externally (Cost: 2113.50 rupees).
#
# Cross-Warehouse Transfer Recommendations:
# Product P10001: Order 7 units externally for Warehouse WIND01 (External Cost: 2079.50 rupees).
# Product P10001: Order 17 units externally for Warehouse WIND02 (External Cost: 2164.50 rupees).
# Product P10001: Order 13 units externally for Warehouse WIND03 (External Cost: 2130.50 rupees).
# Product P10001: Order 37 units externally for Warehouse WIND04 (External Cost: 2334.50 rupees).
# Product P10001: Order 37 units externally for Warehouse WIND04 (External Cost: 2334.50 rupees).
# Product P10001: Transfer 2 units from Warehouse WIND07 to Warehouse WIND04 (Transfer Cost: 1800.00 rupees).
# Product P10002: Order 24 units externally for Warehouse WIND01 (External Cost: 2224.00 rupees).
# Product P10002: Order 58 units externally for Warehouse WIND02 (External Cost: 2513.00 rupees).
# Product P10002: Order 58 units externally for Warehouse WIND02 (External Cost: 2513.00 rupees).
# Product P10002: Order 58 units externally for Warehouse WIND02 (External Cost: 2513.00 rupees).
# Product P10003: Order 33 units externally for Warehouse WIND01 (External Cost: 2300.50 rupees).
# Product P10003: Order 33 units externally for Warehouse WIND01 (External Cost: 2300.50 rupees).
# Product P10004: Order 32 units externally for Warehouse WIND01 (External Cost: 2292.00 rupees).
# Product P10004: Order 32 units externally for Warehouse WIND01 (External Cost: 2292.00 rupees).
# Product P10005: Order 6 units externally for Warehouse WIND04 (External Cost: 2071.00 rupees).
# Product P10005: Order 57 units externally for Warehouse WIND05 (External Cost: 2504.50 rupees).
# Product P10005: Order 57 units externally for Warehouse WIND05 (External Cost: 2504.50 rupees).
# Product P10005: Order 57 units externally for Warehouse WIND05 (External Cost: 2504.50 rupees).
# Product P10006: Order 33 units externally for Warehouse WIND01 (External Cost: 2300.50 rupees).
# Product P10006: Order 7 units externally for Warehouse WIND03 (External Cost: 2079.50 rupees).
# Product P10006: Order 34 units externally for Warehouse WIND04 (External Cost: 2309.00 rupees).
# Product P10006: Order 12 units externally for Warehouse WIND05 (External Cost: 2122.00 rupees).
# Product P10007: Order 44 units externally for Warehouse WIND01 (External Cost: 2394.00 rupees).
# Product P10007: Order 30 units externally for Warehouse WIND02 (External Cost: 2275.00 rupees).
# Product P10008: Order 40 units externally for Warehouse WIND03 (External Cost: 2360.00 rupees).
# Product P10008: Order 19 units externally for Warehouse WIND04 (External Cost: 2181.50 rupees).
# Product P10008: Order 30 units externally for Warehouse WIND06 (External Cost: 2275.00 rupees).
# Product P10008: Order 30 units externally for Warehouse WIND06 (External Cost: 2275.00 rupees).
# Product P10008: Order 30 units externally for Warehouse WIND06 (External Cost: 2275.00 rupees).
# Product P10008: Order 6 units externally for Warehouse WIND07 (External Cost: 2071.00 rupees).
# Product P10009: Transfer 1 units from Warehouse WIND01 to Warehouse WIND04 (Transfer Cost: 1200.00 rupees).
# Product P10009: Order 2 units externally for Warehouse WIND04 (External Cost: 2037.00 rupees).
# Product P10009: Order 18 units externally for Warehouse WIND05 (External Cost: 2173.00 rupees).
# Product P10009: Order 18 units externally for Warehouse WIND05 (External Cost: 2173.00 rupees).
# Product P10009: Order 5 units externally for Warehouse WIND07 (External Cost: 2062.50 rupees).
# Product P10010: Order 18 units externally for Warehouse WIND01 (External Cost: 2173.00 rupees).
# Product P10010: Order 18 units externally for Warehouse WIND01 (External Cost: 2173.00 rupees).
# Product P10010: Transfer 1 units from Warehouse WIND06 to Warehouse WIND02 (Transfer Cost: 1500.00 rupees).

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
import datetime

# -------------------------------------------------
# MongoDB Connection using your provided connection string
# -------------------------------------------------
connection_string = "mongodb+srv://himavarshithreddy:invenx@invenx.kxiph.mongodb.net/?retryWrites=true&w=majority&appName=InvenX"
client = MongoClient(connection_string)
db = client["InvenX"]

# -------------------------------------------------
# Retrieve Inventory Data
# -------------------------------------------------
inventory_collection = db["inventory"]
inventory_docs = list(inventory_collection.find({}, {
    "_id": 0,
    "warehouse_id": 1,
    "product_id": 1,
    "current_stock": 1,
    "min_stock": 1,
    "max_stock": 1,
    "last_updated": 1,
    "forecast_value": 1
}))
inventory_df = pd.DataFrame(inventory_docs)
print("Inventory Data:")
print(inventory_df)

# -------------------------------------------------
# Retrieve Warehouse Data (for ordering_cost)
# Note: Collection name is "warehouse" (singular)
# -------------------------------------------------
warehouse_collection = db["warehouse"]
warehouse_docs = list(warehouse_collection.find({}, {
    "_id": 1,           # Use _id as the warehouse identifier
    "ordering_cost": 1
}))
warehouses_df = pd.DataFrame(warehouse_docs)
if not warehouses_df.empty:
    if "_id" in warehouses_df.columns:
        warehouses_df = warehouses_df.rename(columns={"_id": "warehouse_id"})
else:
    print("Warning: Warehouse Data is empty; using default ordering cost.")

print("\nWarehouse Data:")
print(warehouses_df)

# -------------------------------------------------
# Retrieve Warehouse Transfers Data (for transfer cost)
# -------------------------------------------------
warehouse_transfers_collection = db["warehouse_transfers"]
warehouse_transfers_docs = list(warehouse_transfers_collection.find({}, {
    "_id": 0,
    "source_warehouse_id": 1,
    "destination_warehouse_id": 1,
    "transfer_cost": 1,
    "currency": 1,
    "estimated_transfer_time": 1
}))
warehouse_transfers_df = pd.DataFrame(warehouse_transfers_docs)
print("\nWarehouse Transfers Data:")
print(warehouse_transfers_df)

# -------------------------------------------------
# Merge Inventory with Warehouse Data to Include Ordering Cost
# -------------------------------------------------
default_ordering_cost = 2000.0  # Default ordering cost if warehouse data is missing
if warehouses_df.empty or "ordering_cost" not in warehouses_df.columns:
    inventory_df["ordering_cost"] = default_ordering_cost
else:
    inventory_df = pd.merge(inventory_df, warehouses_df[["warehouse_id", "ordering_cost"]],
                              on="warehouse_id", how="left")
    inventory_df["ordering_cost"] = inventory_df["ordering_cost"].fillna(default_ordering_cost)

print("\nInventory Data after merging ordering cost:")
print(inventory_df)

# -------------------------------------------------
# Configuration: Cost Parameters and Safety Factor
# -------------------------------------------------
# For external ordering, we use the warehouse ordering_cost as a per-unit cost.
# Internal transfer cost uses the transfer_cost from the transfer record or a default per-unit cost.
default_per_unit_transfer_cost = 15.0  # Default per-unit transfer cost if no record is found
safety_factor = 0.2  # 20% safety factor

# -------------------------------------------------
# Step 1: Compute Dynamic Safety Stock and Difference
# -------------------------------------------------
# Calculate dynamic safety stock: dynamic_min_stock = forecast_value * (1 + safety_factor).round())
# Compute difference (diff) using dynamic safety stock as the target:
# diff = current_stock - dynamic_min_stock (negative: deficit; positive: surplus)
inventory_df['diff'] = inventory_df['current_stock'] - inventory_df['dynamic_min_stock']

# -------------------------------------------------
# Step 2: Generate Individual Warehouse Recommendations (External Ordering)
# -------------------------------------------------
individual_recommendations = {}

for idx, row in inventory_df.iterrows():
    prod = row["product_id"]
    ware = row["warehouse_id"]
    current_stock = row["current_stock"]
    forecast_value = row["forecast_value"]
    dynamic_min = row["dynamic_min_stock"]
    diff = row["diff"]
    min_stock = row["min_stock"]
    max_stock = row["max_stock"]
    order_cost = row["ordering_cost"]

    rec_message = ""
    external_order_cost = None

    # Calculate deficit based on dynamic safety stock
    if current_stock < dynamic_min:
        deficit = dynamic_min - current_stock
        # External ordering cost: simply multiply the deficit by the warehouse's ordering cost
        external_order_cost = order_cost * deficit
        rec_message += f"Needs to order {deficit:.0f} units externally (Cost: {external_order_cost:.2f} rupees). "
    else:
        surplus = current_stock - dynamic_min
        rec_message += f"Has excess of {surplus:.0f} units; will attempt internal transfer. "

    # Additional alerts based on fixed thresholds.
    if current_stock < min_stock:
        rec_message += "Stock is below the fixed minimum threshold! "
    if current_stock > max_stock:
        rec_message += "Stock exceeds the maximum limit; consider reducing inventory. "

    individual_recommendations[(prod, ware)] = {
        "current_stock": current_stock,
        "forecast_value": forecast_value,
        "dynamic_min_stock": dynamic_min,
        "diff": diff,
        "external_order_cost": external_order_cost,
        "recommendation": rec_message
    }

print("\nIndividual Inventory Recommendations:")
for (prod, ware), rec in individual_recommendations.items():
    print(f"\nProduct {prod} in Warehouse {ware}:")
    print(f"  Current Stock: {rec['current_stock']}")
    print(f"  Forecasted Demand: {rec['forecast_value']}")
    print(f"  Dynamic Safety Stock: {rec['dynamic_min_stock']:.2f}")
    print(f"  Diff (Current - Dynamic): {rec['diff']:.2f}")
    print(f"  External Ordering Cost: {rec['external_order_cost']}")
    print(f"  Recommendation: {rec['recommendation']}")

# -------------------------------------------------
# Step 3: Generate Cross-Warehouse Transfer Recommendations
# -------------------------------------------------
transfer_recommendations = {}

# Group inventory data by product_id for cross-warehouse analysis.
for prod, group in inventory_df.groupby("product_id"):
    surplus_list = []  # List of tuples: (warehouse_id, surplus_amount)
    deficit_list = []  # List of tuples: (warehouse_id, deficit_amount)

    for idx, row in group.iterrows():
        wh = row["warehouse_id"]
        # Calculate difference relative to dynamic safety stock
        diff = row["current_stock"] - row["dynamic_min_stock"]
        if diff > 0:
            surplus_list.append((wh, diff))
        elif diff < 0:
            deficit_list.append((wh, -diff))  # Store deficit as positive number

    # For each deficit warehouse, try to cover it with surplus from other warehouses.
    for d_idx, (def_wh, def_qty) in enumerate(deficit_list):
        while def_qty > 0 and surplus_list:
            candidate_transfers = []
            for s_idx, (surp_wh, surp_qty) in enumerate(surplus_list):
                if surp_qty > 0:
                    transfer_qty = min(surp_qty, def_qty)
                    # Look up transfer cost between surp_wh and def_wh from warehouse_transfers_df.
                    transfer_record = warehouse_transfers_df[
                        (warehouse_transfers_df["source_warehouse_id"] == surp_wh) &
                        (warehouse_transfers_df["destination_warehouse_id"] == def_wh)
                    ]
                    if not transfer_record.empty:
                        cost_per_unit = float(transfer_record.iloc[0]["transfer_cost"])
                    else:
                        cost_per_unit = default_per_unit_transfer_cost
                    total_transfer_cost = cost_per_unit * transfer_qty
                    candidate_transfers.append((surp_wh, transfer_qty, total_transfer_cost, s_idx))
            if candidate_transfers:
                # Choose the candidate with the lowest total transfer cost.
                best_candidate = min(candidate_transfers, key=lambda x: x[2])
                best_surp_wh, transfer_qty, total_transfer_cost, best_idx = best_candidate
                key = (prod, best_surp_wh, def_wh)
                transfer_recommendations[key] = transfer_recommendations.get(key, 0) + transfer_qty
                surplus_list[best_idx] = (best_surp_wh, surplus_list[best_idx][1] - transfer_qty)
                def_qty -= transfer_qty
            else:
                break
        if def_qty > 0:
            key = (prod, def_wh, "EXTERNAL")
            transfer_recommendations[key] = f"Order {def_qty:.0f} units externally for Warehouse {def_wh}."

print("\nCross-Warehouse Transfer Recommendations:")
if transfer_recommendations:
    for key, rec in transfer_recommendations.items():
        if key[2] == "EXTERNAL":
            print(f"Product {key[0]} in Warehouse {key[1]}: {rec}")
        else:
            print(f"Product {key[0]}: Transfer {rec:.0f} units from Warehouse {key[1]} to Warehouse {key[2]}.")
else:
    print("No internal transfer recommendations available.")
# Out:
# Inventory Data:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56          9        100
# 1        WIND01     P10002             43         10        100
# 2        WIND01     P10003             32         15        100
# 3        WIND01     P10004             29          9        100
# 4        WIND01     P10005             59          7        100
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15         14        100
# 66       WIND07     P10007             12         12        100
# 67       WIND07     P10008             27         15        100
# 68       WIND07     P10009             42         11        100
# 69       WIND07     P10010             53         13        100
#
#             last_updated  forecast_value
# 0   2025-02-10T10:00:00Z              63
# 1   2025-02-10T10:00:00Z              67
# 2   2025-02-10T10:00:00Z              65
# 3   2025-02-10T10:00:00Z              61
# 4   2025-02-10T10:00:00Z              26
# ..                   ...             ...
# 65  2025-02-10T10:00:00Z              47
# 66  2025-02-10T10:00:00Z             -34
# 67  2025-02-10T10:00:00Z              33
# 68  2025-02-10T10:00:00Z              47
# 69  2025-02-10T10:00:00Z              64
#
# [70 rows x 7 columns]
#
# Warehouse Data:
#   warehouse_id  ordering_cost
# 0       WIND01         2000.0
# 1       WIND02            NaN
# 2       WIND03            NaN
# 3       WIND04            NaN
# 4       WIND05            NaN
# 5       WIND06            NaN
# 6       WIND07            NaN
#
# Warehouse Transfers Data:
#    source_warehouse_id destination_warehouse_id  transfer_cost currency  \
# 0               WIND01                   WIND02           2000      INR
# 1               WIND01                   WIND03           1500      INR
# 2               WIND01                   WIND04           1200      INR
# 3               WIND01                   WIND05           1300      INR
# 4               WIND01                   WIND06           1800      INR
# 5               WIND01                   WIND07            500      INR
# 6               WIND02                   WIND01           2000      INR
# 7               WIND02                   WIND03           2200      INR
# 8               WIND02                   WIND04           2000      INR
# 9               WIND02                   WIND05           2100      INR
# 10              WIND02                   WIND06           1500      INR
# 11              WIND02                   WIND07           1900      INR
# 12              WIND03                   WIND01           1500      INR
# 13              WIND03                   WIND02           2200      INR
# 14              WIND03                   WIND04            800      INR
# 15              WIND03                   WIND05            900      INR
# 16              WIND03                   WIND06           1700      INR
# 17              WIND03                   WIND07           1000      INR
# 18              WIND04                   WIND01           1200      INR
# 19              WIND04                   WIND02           2000      INR
# 20              WIND04                   WIND03            800      INR
# 21              WIND04                   WIND05            700      INR
# 22              WIND04                   WIND06           1600      INR
# 23              WIND04                   WIND07            900      INR
# 24              WIND05                   WIND01           1300      INR
# 25              WIND05                   WIND02           2100      INR
# 26              WIND05                   WIND03            900      INR
# 27              WIND05                   WIND04            700      INR
# 28              WIND05                   WIND06           1800      INR
# 29              WIND05                   WIND07           1100      INR
# 30              WIND06                   WIND01           1800      INR
# 31              WIND06                   WIND02           1500      INR
# 32              WIND06                   WIND03           1700      INR
# 33              WIND06                   WIND04           1600      INR
# 34              WIND06                   WIND05           1800      INR
# 35              WIND06                   WIND07           1900      INR
# 36              WIND07                   WIND01            500      INR
# 37              WIND07                   WIND02           1900      INR
# 38              WIND07                   WIND03           1000      INR
# 39              WIND07                   WIND04            900      INR
# 40              WIND07                   WIND05           1100      INR
# 41              WIND07                   WIND06           1900      INR
#
#    estimated_transfer_time
# 0                   2 days
# 1                   2 days
# 2                 1.5 days
# 3                   2 days
# 4                   2 days
# 5                    1 day
# 6                   2 days
# 7                   2 days
# 8                   2 days
# 9                   2 days
# 10                1.5 days
# 11                  2 days
# 12                  2 days
# 13                  2 days
# 14                   1 day
# 15                   1 day
# 16                  2 days
# 17                   1 day
# 18                1.5 days
# 19                  2 days
# 20                   1 day
# 21                   1 day
# 22                  2 days
# 23                   1 day
# 24                  2 days
# 25                  2 days
# 26                   1 day
# 27                   1 day
# 28                  2 days
# 29                1.5 days
# 30                  2 days
# 31                1.5 days
# 32                  2 days
# 33                  2 days
# 34                  2 days
# 35                  2 days
# 36                   1 day
# 37                  2 days
# 38                   1 day
# 39                   1 day
# 40                1.5 days
# 41                  2 days
#
# Inventory Data after merging ordering cost:
#    warehouse_id product_id  current_stock  min_stock  max_stock  \
# 0        WIND01     P10001             56          9        100
# 1        WIND01     P10002             43         10        100
# 2        WIND01     P10003             32         15        100
# 3        WIND01     P10004             29          9        100
# 4        WIND01     P10005             59          7        100
# ..          ...        ...            ...        ...        ...
# 65       WIND07     P10006             15         14        100
# 66       WIND07     P10007             12         12        100
# 67       WIND07     P10008             27         15        100
# 68       WIND07     P10009             42         11        100
# 69       WIND07     P10010             53         13        100
#
#             last_updated  forecast_value  ordering_cost
# 0   2025-02-10T10:00:00Z              63         2000.0
# 1   2025-02-10T10:00:00Z              67         2000.0
# 2   2025-02-10T10:00:00Z              65         2000.0
# 3   2025-02-10T10:00:00Z              61         2000.0
# 4   2025-02-10T10:00:00Z              26         2000.0
# ..                   ...             ...            ...
# 65  2025-02-10T10:00:00Z              47         2000.0
# 66  2025-02-10T10:00:00Z             -34         2000.0
# 67  2025-02-10T10:00:00Z              33         2000.0
# 68  2025-02-10T10:00:00Z              47         2000.0
# 69  2025-02-10T10:00:00Z              64         2000.0
#
# [70 rows x 8 columns]
#
# Individual Inventory Recommendations:
#
# Product P10001 in Warehouse WIND01:
#   Current Stock: 56
#   Forecasted Demand: 63
#   Dynamic Safety Stock: 75.60
#   Diff (Current - Dynamic): -19.60
#   External Ordering Cost: 39199.999999999985
#   Recommendation: Needs to order 20 units externally (Cost: 39200.00 rupees).
#
# Product P10002 in Warehouse WIND01:
#   Current Stock: 43
#   Forecasted Demand: 67
#   Dynamic Safety Stock: 80.40
#   Diff (Current - Dynamic): -37.40
#   External Ordering Cost: 74799.99999999999
#   Recommendation: Needs to order 37 units externally (Cost: 74800.00 rupees).
#
# Product P10003 in Warehouse WIND01:
#   Current Stock: 32
#   Forecasted Demand: 65
#   Dynamic Safety Stock: 78.00
#   Diff (Current - Dynamic): -46.00
#   External Ordering Cost: 92000.0
#   Recommendation: Needs to order 46 units externally (Cost: 92000.00 rupees).
#
# Product P10004 in Warehouse WIND01:
#   Current Stock: 29
#   Forecasted Demand: 61
#   Dynamic Safety Stock: 73.20
#   Diff (Current - Dynamic): -44.20
#   External Ordering Cost: 88400.0
#   Recommendation: Needs to order 44 units externally (Cost: 88400.00 rupees).
#
# Product P10005 in Warehouse WIND01:
#   Current Stock: 59
#   Forecasted Demand: 26
#   Dynamic Safety Stock: 31.20
#   Diff (Current - Dynamic): 27.80
#   External Ordering Cost: None
#   Recommendation: Has excess of 28 units; will attempt internal transfer.
#
# Product P10006 in Warehouse WIND01:
#   Current Stock: 47
#   Forecasted Demand: 80
#   Dynamic Safety Stock: 96.00
#   Diff (Current - Dynamic): -49.00
#   External Ordering Cost: 98000.0
#   Recommendation: Needs to order 49 units externally (Cost: 98000.00 rupees).
#
# Product P10007 in Warehouse WIND01:
#   Current Stock: 33
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.40
#   Diff (Current - Dynamic): -59.40
#   External Ordering Cost: 118799.99999999999
#   Recommendation: Needs to order 59 units externally (Cost: 118800.00 rupees).
#
# Product P10008 in Warehouse WIND01:
#   Current Stock: 87
#   Forecasted Demand: 23
#   Dynamic Safety Stock: 27.60
#   Diff (Current - Dynamic): 59.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 59 units; will attempt internal transfer.
#
# Product P10009 in Warehouse WIND01:
#   Current Stock: 99
#   Forecasted Demand: 98
#   Dynamic Safety Stock: 117.60
#   Diff (Current - Dynamic): -18.60
#   External Ordering Cost: 37199.999999999985
#   Recommendation: Needs to order 19 units externally (Cost: 37200.00 rupees).
#
# Product P10010 in Warehouse WIND01:
#   Current Stock: 25
#   Forecasted Demand: 43
#   Dynamic Safety Stock: 51.60
#   Diff (Current - Dynamic): -26.60
#   External Ordering Cost: 53200.0
#   Recommendation: Needs to order 27 units externally (Cost: 53200.00 rupees).
#
# Product P10001 in Warehouse WIND02:
#   Current Stock: 40
#   Forecasted Demand: 57
#   Dynamic Safety Stock: 68.40
#   Diff (Current - Dynamic): -28.40
#   External Ordering Cost: 56799.999999999985
#   Recommendation: Needs to order 28 units externally (Cost: 56800.00 rupees).
#
# Product P10002 in Warehouse WIND02:
#   Current Stock: 10
#   Forecasted Demand: 68
#   Dynamic Safety Stock: 81.60
#   Diff (Current - Dynamic): -71.60
#   External Ordering Cost: 143200.0
#   Recommendation: Needs to order 72 units externally (Cost: 143200.00 rupees).
#
# Product P10003 in Warehouse WIND02:
#   Current Stock: 69
#   Forecasted Demand: 74
#   Dynamic Safety Stock: 88.80
#   Diff (Current - Dynamic): -19.80
#   External Ordering Cost: 39599.99999999999
#   Recommendation: Needs to order 20 units externally (Cost: 39600.00 rupees).
#
# Product P10004 in Warehouse WIND02:
#   Current Stock: 73
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 58.80
#   Diff (Current - Dynamic): 14.20
#   External Ordering Cost: None
#   Recommendation: Has excess of 14 units; will attempt internal transfer.
#
# Product P10005 in Warehouse WIND02:
#   Current Stock: 84
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 57.60
#   Diff (Current - Dynamic): 26.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 26 units; will attempt internal transfer.
#
# Product P10006 in Warehouse WIND02:
#   Current Stock: 94
#   Forecasted Demand: 17
#   Dynamic Safety Stock: 20.40
#   Diff (Current - Dynamic): 73.60
#   External Ordering Cost: None
#   Recommendation: Has excess of 74 units; will attempt internal transfer.
#
# Product P10007 in Warehouse WIND02:
#   Current Stock: 19
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 58.80
#   Diff (Current - Dynamic): -39.80
#   External Ordering Cost: 79600.0
#   Recommendation: Needs to order 40 units externally (Cost: 79600.00 rupees).
#
# Product P10008 in Warehouse WIND02:
#   Current Stock: 77
#   Forecasted Demand: 52
#   Dynamic Safety Stock: 62.40
#   Diff (Current - Dynamic): 14.60
#   External Ordering Cost: None
#   Recommendation: Has excess of 15 units; will attempt internal transfer.
#
# Product P10009 in Warehouse WIND02:
#   Current Stock: 63
#   Forecasted Demand: 45
#   Dynamic Safety Stock: 54.00
#   Diff (Current - Dynamic): 9.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 9 units; will attempt internal transfer.
#
# Product P10010 in Warehouse WIND02:
#   Current Stock: 43
#   Forecasted Demand: 118
#   Dynamic Safety Stock: 141.60
#   Diff (Current - Dynamic): -98.60
#   External Ordering Cost: 197200.0
#   Recommendation: Needs to order 99 units externally (Cost: 197200.00 rupees).
#
# Product P10001 in Warehouse WIND03:
#   Current Stock: 36
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 58.80
#   Diff (Current - Dynamic): -22.80
#   External Ordering Cost: 45599.99999999999
#   Recommendation: Needs to order 23 units externally (Cost: 45600.00 rupees).
#
# Product P10002 in Warehouse WIND03:
#   Current Stock: 91
#   Forecasted Demand: 53
#   Dynamic Safety Stock: 63.60
#   Diff (Current - Dynamic): 27.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 27 units; will attempt internal transfer.
#
# Product P10003 in Warehouse WIND03:
#   Current Stock: 45
#   Forecasted Demand: 76
#   Dynamic Safety Stock: 91.20
#   Diff (Current - Dynamic): -46.20
#   External Ordering Cost: 92400.0
#   Recommendation: Needs to order 46 units externally (Cost: 92400.00 rupees).
#
# Product P10004 in Warehouse WIND03:
#   Current Stock: 81
#   Forecasted Demand: 58
#   Dynamic Safety Stock: 69.60
#   Diff (Current - Dynamic): 11.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 11 units; will attempt internal transfer.
#
# Product P10005 in Warehouse WIND03:
#   Current Stock: 77
#   Forecasted Demand: 65
#   Dynamic Safety Stock: 78.00
#   Diff (Current - Dynamic): -1.00
#   External Ordering Cost: 2000.0
#   Recommendation: Needs to order 1 units externally (Cost: 2000.00 rupees).
#
# Product P10006 in Warehouse WIND03:
#   Current Stock: 54
#   Forecasted Demand: 61
#   Dynamic Safety Stock: 73.20
#   Diff (Current - Dynamic): -19.20
#   External Ordering Cost: 38400.00000000001
#   Recommendation: Needs to order 19 units externally (Cost: 38400.00 rupees).
#
# Product P10007 in Warehouse WIND03:
#   Current Stock: 35
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.40
#   Diff (Current - Dynamic): -57.40
#   External Ordering Cost: 114799.99999999999
#   Recommendation: Needs to order 57 units externally (Cost: 114800.00 rupees).
#
# Product P10008 in Warehouse WIND03:
#   Current Stock: 37
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.40
#   Diff (Current - Dynamic): -55.40
#   External Ordering Cost: 110799.99999999999
#   Recommendation: Needs to order 55 units externally (Cost: 110800.00 rupees).
#
# Product P10009 in Warehouse WIND03:
#   Current Stock: 73
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 57.60
#   Diff (Current - Dynamic): 15.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 15 units; will attempt internal transfer.
#
# Product P10010 in Warehouse WIND03:
#   Current Stock: 28
#   Forecasted Demand: 112
#   Dynamic Safety Stock: 134.40
#   Diff (Current - Dynamic): -106.40
#   External Ordering Cost: 212800.0
#   Recommendation: Needs to order 106 units externally (Cost: 212800.00 rupees).
#
# Product P10001 in Warehouse WIND04:
#   Current Stock: 29
#   Forecasted Demand: 66
#   Dynamic Safety Stock: 79.20
#   Diff (Current - Dynamic): -50.20
#   External Ordering Cost: 100400.0
#   Recommendation: Needs to order 50 units externally (Cost: 100400.00 rupees).
#
# Product P10002 in Warehouse WIND04:
#   Current Stock: 37
#   Forecasted Demand: 33
#   Dynamic Safety Stock: 39.60
#   Diff (Current - Dynamic): -2.60
#   External Ordering Cost: 5200.000000000003
#   Recommendation: Needs to order 3 units externally (Cost: 5200.00 rupees).
#
# Product P10003 in Warehouse WIND04:
#   Current Stock: 66
#   Forecasted Demand: 56
#   Dynamic Safety Stock: 67.20
#   Diff (Current - Dynamic): -1.20
#   External Ordering Cost: 2400.0000000000055
#   Recommendation: Needs to order 1 units externally (Cost: 2400.00 rupees).
#
# Product P10004 in Warehouse WIND04:
#   Current Stock: 40
#   Forecasted Demand: 78
#   Dynamic Safety Stock: 93.60
#   Diff (Current - Dynamic): -53.60
#   External Ordering Cost: 107199.99999999999
#   Recommendation: Needs to order 54 units externally (Cost: 107200.00 rupees).
#
# Product P10005 in Warehouse WIND04:
#   Current Stock: 39
#   Forecasted Demand: 45
#   Dynamic Safety Stock: 54.00
#   Diff (Current - Dynamic): -15.00
#   External Ordering Cost: 30000.0
#   Recommendation: Needs to order 15 units externally (Cost: 30000.00 rupees).
#
# Product P10006 in Warehouse WIND04:
#   Current Stock: 54
#   Forecasted Demand: 88
#   Dynamic Safety Stock: 105.60
#   Diff (Current - Dynamic): -51.60
#   External Ordering Cost: 103199.99999999999
#   Recommendation: Needs to order 52 units externally (Cost: 103200.00 rupees).
#
# Product P10007 in Warehouse WIND04:
#   Current Stock: 77
#   Forecasted Demand: 87
#   Dynamic Safety Stock: 104.40
#   Diff (Current - Dynamic): -27.40
#   External Ordering Cost: 54799.999999999985
#   Recommendation: Needs to order 27 units externally (Cost: 54800.00 rupees).
#
# Product P10008 in Warehouse WIND04:
#   Current Stock: 49
#   Forecasted Demand: 68
#   Dynamic Safety Stock: 81.60
#   Diff (Current - Dynamic): -32.60
#   External Ordering Cost: 65199.999999999985
#   Recommendation: Needs to order 33 units externally (Cost: 65200.00 rupees).
#
# Product P10009 in Warehouse WIND04:
#   Current Stock: 75
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.40
#   Diff (Current - Dynamic): -17.40
#   External Ordering Cost: 34799.999999999985
#   Recommendation: Needs to order 17 units externally (Cost: 34800.00 rupees).
#
# Product P10010 in Warehouse WIND04:
#   Current Stock: 35
#   Forecasted Demand: 53
#   Dynamic Safety Stock: 63.60
#   Diff (Current - Dynamic): -28.60
#   External Ordering Cost: 57199.999999999985
#   Recommendation: Needs to order 29 units externally (Cost: 57200.00 rupees).
#
# Product P10001 in Warehouse WIND05:
#   Current Stock: 88
#   Forecasted Demand: 47
#   Dynamic Safety Stock: 56.40
#   Diff (Current - Dynamic): 31.60
#   External Ordering Cost: None
#   Recommendation: Has excess of 32 units; will attempt internal transfer.
#
# Product P10002 in Warehouse WIND05:
#   Current Stock: 72
#   Forecasted Demand: 49
#   Dynamic Safety Stock: 58.80
#   Diff (Current - Dynamic): 13.20
#   External Ordering Cost: None
#   Recommendation: Has excess of 13 units; will attempt internal transfer.
#
# Product P10003 in Warehouse WIND05:
#   Current Stock: 66
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 57.60
#   Diff (Current - Dynamic): 8.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 8 units; will attempt internal transfer.
#
# Product P10004 in Warehouse WIND05:
#   Current Stock: 51
#   Forecasted Demand: 84
#   Dynamic Safety Stock: 100.80
#   Diff (Current - Dynamic): -49.80
#   External Ordering Cost: 99600.0
#   Recommendation: Needs to order 50 units externally (Cost: 99600.00 rupees).
#
# Product P10005 in Warehouse WIND05:
#   Current Stock: 25
#   Forecasted Demand: 82
#   Dynamic Safety Stock: 98.40
#   Diff (Current - Dynamic): -73.40
#   External Ordering Cost: 146799.99999999997
#   Recommendation: Needs to order 73 units externally (Cost: 146800.00 rupees).
#
# Product P10006 in Warehouse WIND05:
#   Current Stock: 31
#   Forecasted Demand: 43
#   Dynamic Safety Stock: 51.60
#   Diff (Current - Dynamic): -20.60
#   External Ordering Cost: 41200.0
#   Recommendation: Needs to order 21 units externally (Cost: 41200.00 rupees).
#
# Product P10007 in Warehouse WIND05:
#   Current Stock: 47
#   Forecasted Demand: 70
#   Dynamic Safety Stock: 84.00
#   Diff (Current - Dynamic): -37.00
#   External Ordering Cost: 74000.0
#   Recommendation: Needs to order 37 units externally (Cost: 74000.00 rupees).
#
# Product P10008 in Warehouse WIND05:
#   Current Stock: 52
#   Forecasted Demand: 5
#   Dynamic Safety Stock: 6.00
#   Diff (Current - Dynamic): 46.00
#   External Ordering Cost: None
#   Recommendation: Has excess of 46 units; will attempt internal transfer.
#
# Product P10009 in Warehouse WIND05:
#   Current Stock: 33
#   Forecasted Demand: 51
#   Dynamic Safety Stock: 61.20
#   Diff (Current - Dynamic): -28.20
#   External Ordering Cost: 56399.99999999999
#   Recommendation: Needs to order 28 units externally (Cost: 56400.00 rupees).
#
# Product P10010 in Warehouse WIND05:
#   Current Stock: 58
#   Forecasted Demand: 48
#   Dynamic Safety Stock: 57.60
#   Diff (Current - Dynamic): 0.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 0 units; will attempt internal transfer.
#
# Product P10001 in Warehouse WIND06:
#   Current Stock: 80
#   Forecasted Demand: 77
#   Dynamic Safety Stock: 92.40
#   Diff (Current - Dynamic): -12.40
#   External Ordering Cost: 24799.99999999998
#   Recommendation: Needs to order 12 units externally (Cost: 24800.00 rupees).
#
# Product P10002 in Warehouse WIND06:
#   Current Stock: 63
#   Forecasted Demand: 74
#   Dynamic Safety Stock: 88.80
#   Diff (Current - Dynamic): -25.80
#   External Ordering Cost: 51599.99999999999
#   Recommendation: Needs to order 26 units externally (Cost: 51600.00 rupees).
#
# Product P10003 in Warehouse WIND06:
#   Current Stock: 38
#   Forecasted Demand: 89
#   Dynamic Safety Stock: 106.80
#   Diff (Current - Dynamic): -68.80
#   External Ordering Cost: 137600.0
#   Recommendation: Needs to order 69 units externally (Cost: 137600.00 rupees).
#
# Product P10004 in Warehouse WIND06:
#   Current Stock: 26
#   Forecasted Demand: 90
#   Dynamic Safety Stock: 108.00
#   Diff (Current - Dynamic): -82.00
#   External Ordering Cost: 164000.0
#   Recommendation: Needs to order 82 units externally (Cost: 164000.00 rupees).
#
# Product P10005 in Warehouse WIND06:
#   Current Stock: 31
#   Forecasted Demand: 57
#   Dynamic Safety Stock: 68.40
#   Diff (Current - Dynamic): -37.40
#   External Ordering Cost: 74799.99999999999
#   Recommendation: Needs to order 37 units externally (Cost: 74800.00 rupees).
#
# Product P10006 in Warehouse WIND06:
#   Current Stock: 47
#   Forecasted Demand: 63
#   Dynamic Safety Stock: 75.60
#   Diff (Current - Dynamic): -28.60
#   External Ordering Cost: 57199.999999999985
#   Recommendation: Needs to order 29 units externally (Cost: 57200.00 rupees).
#
# Product P10007 in Warehouse WIND06:
#   Current Stock: 10
#   Forecasted Demand: 27
#   Dynamic Safety Stock: 32.40
#   Diff (Current - Dynamic): -22.40
#   External Ordering Cost: 44800.0
#   Recommendation: Needs to order 22 units externally (Cost: 44800.00 rupees).
#
# Product P10008 in Warehouse WIND06:
#   Current Stock: 45
#   Forecasted Demand: 75
#   Dynamic Safety Stock: 90.00
#   Diff (Current - Dynamic): -45.00
#   External Ordering Cost: 90000.0
#   Recommendation: Needs to order 45 units externally (Cost: 90000.00 rupees).
#
# Product P10009 in Warehouse WIND06:
#   Current Stock: 49
#   Forecasted Demand: 22
#   Dynamic Safety Stock: 26.40
#   Diff (Current - Dynamic): 22.60
#   External Ordering Cost: None
#   Recommendation: Has excess of 23 units; will attempt internal transfer.
#
# Product P10010 in Warehouse WIND06:
#   Current Stock: 62
#   Forecasted Demand: 43
#   Dynamic Safety Stock: 51.60
#   Diff (Current - Dynamic): 10.40
#   External Ordering Cost: None
#   Recommendation: Has excess of 10 units; will attempt internal transfer.
#
# Product P10001 in Warehouse WIND07:
#   Current Stock: 32
#   Forecasted Demand: 30
#   Dynamic Safety Stock: 36.00
#   Diff (Current - Dynamic): -4.00
#   External Ordering Cost: 8000.0
#   Recommendation: Needs to order 4 units externally (Cost: 8000.00 rupees).
#
# Product P10002 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: 68
#   Dynamic Safety Stock: 81.60
#   Diff (Current - Dynamic): -69.60
#   External Ordering Cost: 139200.0
#   Recommendation: Needs to order 70 units externally (Cost: 139200.00 rupees). Stock is below the fixed minimum threshold!
#
# Product P10003 in Warehouse WIND07:
#   Current Stock: 23
#   Forecasted Demand: 62
#   Dynamic Safety Stock: 74.40
#   Diff (Current - Dynamic): -51.40
#   External Ordering Cost: 102799.99999999999
#   Recommendation: Needs to order 51 units externally (Cost: 102800.00 rupees).
#
# Product P10004 in Warehouse WIND07:
#   Current Stock: 43
#   Forecasted Demand: 69
#   Dynamic Safety Stock: 82.80
#   Diff (Current - Dynamic): -39.80
#   External Ordering Cost: 79600.0
#   Recommendation: Needs to order 40 units externally (Cost: 79600.00 rupees).
#
# Product P10005 in Warehouse WIND07:
#   Current Stock: 20
#   Forecasted Demand: 39
#   Dynamic Safety Stock: 46.80
#   Diff (Current - Dynamic): -26.80
#   External Ordering Cost: 53599.99999999999
#   Recommendation: Needs to order 27 units externally (Cost: 53600.00 rupees).
#
# Product P10006 in Warehouse WIND07:
#   Current Stock: 15
#   Forecasted Demand: 47
#   Dynamic Safety Stock: 56.40
#   Diff (Current - Dynamic): -41.40
#   External Ordering Cost: 82800.0
#   Recommendation: Needs to order 41 units externally (Cost: 82800.00 rupees).
#
# Product P10007 in Warehouse WIND07:
#   Current Stock: 12
#   Forecasted Demand: -34
#   Dynamic Safety Stock: -40.80
#   Diff (Current - Dynamic): 52.80
#   External Ordering Cost: None
#   Recommendation: Has excess of 53 units; will attempt internal transfer.
#
# Product P10008 in Warehouse WIND07:
#   Current Stock: 27
#   Forecasted Demand: 33
#   Dynamic Safety Stock: 39.60
#   Diff (Current - Dynamic): -12.60
#   External Ordering Cost: 25200.000000000004
#   Recommendation: Needs to order 13 units externally (Cost: 25200.00 rupees).
#
# Product P10009 in Warehouse WIND07:
#   Current Stock: 42
#   Forecasted Demand: 47
#   Dynamic Safety Stock: 56.40
#   Diff (Current - Dynamic): -14.40
#   External Ordering Cost: 28799.999999999996
#   Recommendation: Needs to order 14 units externally (Cost: 28800.00 rupees).
#
# Product P10010 in Warehouse WIND07:
#   Current Stock: 53
#   Forecasted Demand: 64
#   Dynamic Safety Stock: 76.80
#   Diff (Current - Dynamic): -23.80
#   External Ordering Cost: 47599.99999999999
#   Recommendation: Needs to order 24 units externally (Cost: 47600.00 rupees).
#
# Cross-Warehouse Transfer Recommendations:
# Product P10001: Transfer 20 units from Warehouse WIND05 to Warehouse WIND01.
# Product P10001: Transfer 12 units from Warehouse WIND05 to Warehouse WIND02.
# Product P10001 in Warehouse WIND02: Order 16 units externally for Warehouse WIND02.
# Product P10001 in Warehouse WIND03: Order 23 units externally for Warehouse WIND03.
# Product P10001 in Warehouse WIND04: Order 50 units externally for Warehouse WIND04.
# Product P10001 in Warehouse WIND06: Order 12 units externally for Warehouse WIND06.
# Product P10001 in Warehouse WIND07: Order 4 units externally for Warehouse WIND07.
# Product P10002: Transfer 13 units from Warehouse WIND05 to Warehouse WIND01.
# Product P10002: Transfer 24 units from Warehouse WIND03 to Warehouse WIND01.
# Product P10002: Transfer 3 units from Warehouse WIND03 to Warehouse WIND02.
# Product P10002 in Warehouse WIND02: Order 68 units externally for Warehouse WIND02.
# Product P10002 in Warehouse WIND04: Order 3 units externally for Warehouse WIND04.
# Product P10002 in Warehouse WIND06: Order 26 units externally for Warehouse WIND06.
# Product P10002 in Warehouse WIND07: Order 70 units externally for Warehouse WIND07.
# Product P10003: Transfer 8 units from Warehouse WIND05 to Warehouse WIND01.
# Product P10003 in Warehouse WIND01: Order 38 units externally for Warehouse WIND01.
# Product P10003 in Warehouse WIND02: Order 20 units externally for Warehouse WIND02.
# Product P10003 in Warehouse WIND03: Order 46 units externally for Warehouse WIND03.
# Product P10003 in Warehouse WIND04: Order 1 units externally for Warehouse WIND04.
# Product P10003 in Warehouse WIND06: Order 69 units externally for Warehouse WIND06.
# Product P10003 in Warehouse WIND07: Order 51 units externally for Warehouse WIND07.
# Product P10004: Transfer 11 units from Warehouse WIND03 to Warehouse WIND01.
# Product P10004: Transfer 14 units from Warehouse WIND02 to Warehouse WIND01.
# Product P10004 in Warehouse WIND01: Order 19 units externally for Warehouse WIND01.
# Product P10004 in Warehouse WIND04: Order 54 units externally for Warehouse WIND04.
# Product P10004 in Warehouse WIND05: Order 50 units externally for Warehouse WIND05.
# Product P10004 in Warehouse WIND06: Order 82 units externally for Warehouse WIND06.
# Product P10004 in Warehouse WIND07: Order 40 units externally for Warehouse WIND07.
# Product P10005: Transfer 1 units from Warehouse WIND01 to Warehouse WIND03.
# Product P10005: Transfer 15 units from Warehouse WIND01 to Warehouse WIND04.
# Product P10005: Transfer 12 units from Warehouse WIND01 to Warehouse WIND05.
# Product P10005: Transfer 26 units from Warehouse WIND02 to Warehouse WIND05.
# Product P10005 in Warehouse WIND05: Order 35 units externally for Warehouse WIND05.
# Product P10005 in Warehouse WIND06: Order 37 units externally for Warehouse WIND06.
# Product P10005 in Warehouse WIND07: Order 27 units externally for Warehouse WIND07.
# Product P10006: Transfer 49 units from Warehouse WIND02 to Warehouse WIND01.
# Product P10006: Transfer 19 units from Warehouse WIND02 to Warehouse WIND03.
# Product P10006: Transfer 5 units from Warehouse WIND02 to Warehouse WIND04.
# Product P10006 in Warehouse WIND04: Order 46 units externally for Warehouse WIND04.
# Product P10006 in Warehouse WIND05: Order 21 units externally for Warehouse WIND05.
# Product P10006 in Warehouse WIND06: Order 29 units externally for Warehouse WIND06.
# Product P10006 in Warehouse WIND07: Order 41 units externally for Warehouse WIND07.
# Product P10007: Transfer 53 units from Warehouse WIND07 to Warehouse WIND01.
# Product P10007 in Warehouse WIND01: Order 7 units externally for Warehouse WIND01.
# Product P10007 in Warehouse WIND02: Order 40 units externally for Warehouse WIND02.
# Product P10007 in Warehouse WIND03: Order 57 units externally for Warehouse WIND03.
# Product P10007 in Warehouse WIND04: Order 27 units externally for Warehouse WIND04.
# Product P10007 in Warehouse WIND05: Order 37 units externally for Warehouse WIND05.
# Product P10007 in Warehouse WIND06: Order 22 units externally for Warehouse WIND06.
# Product P10008: Transfer 15 units from Warehouse WIND02 to Warehouse WIND03.
# Product P10008: Transfer 41 units from Warehouse WIND05 to Warehouse WIND03.
# Product P10008: Transfer 5 units from Warehouse WIND05 to Warehouse WIND04.
# Product P10008: Transfer 27 units from Warehouse WIND01 to Warehouse WIND04.
# Product P10008: Transfer 32 units from Warehouse WIND01 to Warehouse WIND06.
# Product P10008 in Warehouse WIND06: Order 13 units externally for Warehouse WIND06.
# Product P10008 in Warehouse WIND07: Order 13 units externally for Warehouse WIND07.
# Product P10009: Transfer 9 units from Warehouse WIND02 to Warehouse WIND01.
# Product P10009: Transfer 10 units from Warehouse WIND03 to Warehouse WIND01.
# Product P10009: Transfer 6 units from Warehouse WIND03 to Warehouse WIND04.
# Product P10009: Transfer 12 units from Warehouse WIND06 to Warehouse WIND04.
# Product P10009: Transfer 11 units from Warehouse WIND06 to Warehouse WIND05.
# Product P10009 in Warehouse WIND05: Order 17 units externally for Warehouse WIND05.
# Product P10009 in Warehouse WIND07: Order 14 units externally for Warehouse WIND07.
# Product P10010: Transfer 0 units from Warehouse WIND05 to Warehouse WIND01.
# Product P10010: Transfer 10 units from Warehouse WIND06 to Warehouse WIND01.
# Product P10010 in Warehouse WIND01: Order 16 units externally for Warehouse WIND01.
# Product P10010 in Warehouse WIND02: Order 99 units externally for Warehouse WIND02.
# Product P10010 in Warehouse WIND03: Order 106 units externally for Warehouse WIND03.
# Product P10010 in Warehouse WIND04: Order 29 units externally for Warehouse WIND04.
# Product P10010 in Warehouse WIND07: Order 24 units externally for Warehouse WIND07.

# %%
# !pip install fastapi uvicorn
# !pip install fastapi uvicorn nest_asyncio pyngrok
# !pip install pymongo
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (0.115.8)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (0.34.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (0.45.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.10.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.46.0,>=0.40.0->fastapi) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (0.115.8)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (0.34.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.11/dist-packages (7.2.3)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (0.45.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.10.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.46.0,>=0.40.0->fastapi) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (1.3.1)
# Collecting pymongo
#   Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 40.8 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 17.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.1

# %%
# !ngrok authtoken 2srYZjcyX06JUQ96HDvj5EOuoUB_3TptwEJJWEF2GpGXim8qN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import nest_asyncio
nest_asyncio.apply()

from fastapi import FastAPI
from fastapi.responses import JSONResponse
import uvicorn
import pandas as pd
import numpy as np
from pymongo import MongoClient
import datetime
from pyngrok import ngrok
from fastapi.middleware.cors import CORSMiddleware

app = FastAPI()

# Enable CORS
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

@app.get("/inventory/optimization")
def get_inventory_optimization():
    # -------------------------------------------------
    # MongoDB Connection
    # -------------------------------------------------
    connection_string = "mongodb+srv://himavarshithreddy:invenx@invenx.kxiph.mongodb.net/?retryWrites=true&w=majority&appName=InvenX"
    client = MongoClient(connection_string)
    db = client["InvenX"]

    # -------------------------------------------------
    # Retrieve Inventory Data
    # -------------------------------------------------
    inventory_collection = db["inventory"]
    inventory_docs = list(inventory_collection.find({}, {
        "_id": 0,
        "warehouse_id": 1,
        "product_id": 1,
        "current_stock": 1,
        "min_stock": 1,
        "max_stock": 1,
        "last_updated": 1,
        "forecast_value": 1
    }))
    inventory_df = pd.DataFrame(inventory_docs)

    # -------------------------------------------------
    # Retrieve Warehouse Data (for ordering_cost) from the "warehouse" collection
    # -------------------------------------------------
    warehouse_collection = db["warehouse"]
    warehouse_docs = list(warehouse_collection.find({}, {
        "_id": 1,
        "ordering_cost": 1
    }))
    warehouses_df = pd.DataFrame(warehouse_docs)
    if not warehouses_df.empty:
        if "_id" in warehouses_df.columns:
            warehouses_df = warehouses_df.rename(columns={"_id": "warehouse_id"})
    else:
        print("Warning: Warehouse Data is empty; using default ordering cost.")

    # -------------------------------------------------
    # Retrieve Warehouse Transfers Data (for transfer cost)
    # -------------------------------------------------
    warehouse_transfers_collection = db["warehouse_transfers"]
    warehouse_transfers_docs = list(warehouse_transfers_collection.find({}, {
        "_id": 0,
        "source_warehouse_id": 1,
        "destination_warehouse_id": 1,
        "transfer_cost": 1,
        "currency": 1,
        "estimated_transfer_time": 1
    }))
    warehouse_transfers_df = pd.DataFrame(warehouse_transfers_docs)

    # -------------------------------------------------
    # Merge Inventory with Warehouse Data to Include Ordering Cost
    # -------------------------------------------------
    default_ordering_cost = 2000.0  # Default ordering cost if warehouse data is missing
    if warehouses_df.empty or "ordering_cost" not in warehouses_df.columns:
        inventory_df["ordering_cost"] = default_ordering_cost
    else:
        inventory_df = pd.merge(inventory_df, warehouses_df[["warehouse_id", "ordering_cost"]],
                                  on="warehouse_id", how="left")
        inventory_df["ordering_cost"] = inventory_df["ordering_cost"].fillna(default_ordering_cost)

    # -------------------------------------------------
    # Configuration: Cost Parameters and Safety Factor
    # -------------------------------------------------
    # For external ordering, we now use: External Ordering Cost = ordering_cost * deficit.
    per_unit_order_cost = 5.0         # (Not used in this simplified cost model)
    external_transport_cost = 20.0    # (Not used in this simplified cost model)
    holding_cost_per_unit_day = 0.5   # (Not used in this simplified cost model)
    forecast_period_days = 7          # (Not used in this simplified cost model)
    default_per_unit_transfer_cost = 15.0  # Default per-unit transfer cost if no transfer record is found
    safety_factor = 0.2               # 20% safety factor

    # -------------------------------------------------
    # Step 1: Compute Dynamic Safety Stock and Difference
    # -------------------------------------------------
    # dynamic_min_stock = forecast_value * (1 + safety_factor)
    inventory_df['dynamic_min_stock'] = (inventory_df['forecast_value'] * (1 + safety_factor)).round()
    # Compute diff = current_stock - dynamic_min_stock (if negative: deficit; if positive: surplus)
    inventory_df['diff'] = inventory_df['current_stock'] - inventory_df['dynamic_min_stock']

    # -------------------------------------------------
    # Step 2: Generate Individual Warehouse Recommendations
    # -------------------------------------------------
    individual_recommendations = {}

    for idx, row in inventory_df.iterrows():
        prod = row["product_id"]
        ware = row["warehouse_id"]
        current_stock = row["current_stock"]
        forecast_value = row["forecast_value"]
        dynamic_min = row["dynamic_min_stock"]
        diff = row["diff"]
        min_stock = row["min_stock"]
        max_stock = row["max_stock"]
        order_cost = row["ordering_cost"]

        rec_message = ""
        external_order_cost_val = None

        # Use dynamic safety stock to determine deficit/surplus.
        if current_stock < dynamic_min:
            deficit = dynamic_min - current_stock
            # External ordering cost: simply multiply the deficit by the warehouse's ordering cost.
            external_order_cost_val = order_cost * deficit
            rec_message += f"Needs to order {deficit:.0f} units externally (Cost: {external_order_cost_val:.2f} rupees). "
        else:
            surplus = current_stock - dynamic_min
            rec_message += f"Has excess of {surplus:.0f} units; will attempt internal transfer. "

        if current_stock < min_stock:
            rec_message += "Stock is below the fixed minimum threshold! "
        if current_stock > max_stock:
            rec_message += "Stock exceeds the maximum limit; consider reducing inventory. "

        individual_recommendations[(prod, ware)] = {
            "current_stock": current_stock,
            "forecast_value": forecast_value,
            "dynamic_min_stock": dynamic_min,
            "diff": diff,
            "external_order_cost": external_order_cost_val,
            "recommendation": rec_message
        }

    # -------------------------------------------------
    # Step 3: Generate Cross-Warehouse Transfer Recommendations
    # -------------------------------------------------
    transfer_recommendations = {}

    # Group inventory data by product for cross-warehouse analysis.
    for prod, group in inventory_df.groupby("product_id"):
        surplus_list = []  # List of tuples: (warehouse_id, surplus_amount)
        deficit_list = []  # List of tuples: (warehouse_id, deficit_amount)

        for idx, row in group.iterrows():
            wh = row["warehouse_id"]
            diff_val = row["current_stock"] - row["dynamic_min_stock"]
            if diff_val > 0:
                surplus_list.append((wh, diff_val))
            elif diff_val < 0:
                deficit_list.append((wh, -diff_val))  # Convert to positive

        # For each deficit warehouse, attempt to cover the deficit using surplus from other warehouses.
        for d_idx, (def_wh, def_qty) in enumerate(deficit_list):
            while def_qty > 0 and surplus_list:
                candidate_transfers = []
                for s_idx, (surp_wh, surp_qty) in enumerate(surplus_list):
                    if surp_qty > 0:
                        transfer_qty = min(surp_qty, def_qty)
                        # Look up transfer cost between surp_wh and def_wh.
                        transfer_record = warehouse_transfers_df[
                            (warehouse_transfers_df["source_warehouse_id"] == surp_wh) &
                            (warehouse_transfers_df["destination_warehouse_id"] == def_wh)
                        ]
                        if not transfer_record.empty:
                            cost_per_unit = float(transfer_record.iloc[0]["transfer_cost"])
                        else:
                            cost_per_unit = default_per_unit_transfer_cost
                        total_transfer_cost = cost_per_unit * transfer_qty
                        candidate_transfers.append((surp_wh, transfer_qty, total_transfer_cost, s_idx))
                if candidate_transfers:
                    best_candidate = min(candidate_transfers, key=lambda x: x[2])
                    best_surp_wh, transfer_qty, total_transfer_cost, best_idx = best_candidate
                    key = (prod, best_surp_wh, def_wh)
                    transfer_recommendations[key] = transfer_recommendations.get(key, 0) + transfer_qty
                    surplus_list[best_idx] = (best_surp_wh, surplus_list[best_idx][1] - transfer_qty)
                    def_qty -= transfer_qty
                else:
                    break
            if def_qty > 0:
                key = (prod, def_wh, "EXTERNAL")
                transfer_recommendations[key] = f"Order {def_qty:.0f} units externally for Warehouse {def_wh}."

    # -------------------------------------------------
    # Return the Combined Recommendations as JSON
    # -------------------------------------------------
    response = {

        "transfer_recommendations": {str(k): v for k, v in transfer_recommendations.items()}
    }
    return JSONResponse(content=response)

# -------------------------------------------------
# Expose the API using ngrok (for Colab)
# -------------------------------------------------
if __name__ == "__main__":
    public_url = ngrok.connect(8000).public_url
    print("Public URL:", public_url)
    uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# INFO:     Started server process [267]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# Public URL: https://d5f7-34-83-161-48.ngrok-free.app
# INFO:     2409:40f4:410a:eae5:d5a6:37d4:79af:2eaa:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS //inventory/optimization HTTP/1.1" 200 OK
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 200 OK
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "GET //inventory/optimization HTTP/1.1" 404 Not Found
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "GET /inventory/optimization HTTP/1.1" 200 OK
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "GET /inventory/optimization HTTP/1.1" 200 OK
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 200 OK
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 200 OK
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "GET /inventory/optimization HTTP/1.1" 200 OK
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "GET /inventory/optimization HTTP/1.1" 200 OK
# INFO:     34.78.26.243:0 - "GET / HTTP/1.1" 404 Not Found

# %%
# !pip install fastapi uvicorn pymongo pyngrok
# Out:
# Collecting fastapi
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pymongo
#   Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyngrok
#   Downloading pyngrok-7.2.3-py3-none-any.whl.metadata (8.7 kB)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.10.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (0.14.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.46.0,>=0.40.0->fastapi) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (1.3.1)
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 5.1 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.4 MB/s eta 0:00:00
# Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.7 MB/s eta 0:00:00
# Downloading pyngrok-7.2.3-py3-none-any.whl (23 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.9 MB/s eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: uvicorn, pyngrok, dnspython, starlette, pymongo, fastapi
# Successfully installed dnspython-2.7.0 fastapi-0.115.8 pymongo-4.11.1 pyngrok-7.2.3 starlette-0.45.3 uvicorn-0.34.0

# %%
import nest_asyncio
nest_asyncio.apply()

from fastapi import FastAPI
from fastapi.responses import JSONResponse
import uvicorn
import pandas as pd
import numpy as np
from pymongo import MongoClient
from pyngrok import ngrok

app = FastAPI()

@app.get("/inventory/optimization")
def get_inventory_optimization():
    # -------------------------------------------------
    # MongoDB Connection
    # -------------------------------------------------
    connection_string = "mongodb+srv://himavarshithreddy:invenx@invenx.kxiph.mongodb.net/?retryWrites=true&w=majority&appName=InvenX"
    client = MongoClient(connection_string)
    db = client["InvenX"]

    # -------------------------------------------------
    # Retrieve Inventory Data
    # -------------------------------------------------
    inventory_collection = db["inventory"]
    inventory_docs = list(inventory_collection.find({}, {
        "_id": 0,
        "warehouse_id": 1,
        "product_id": 1,
        "current_stock": 1,
        "min_stock": 1,
        "max_stock": 1,
        "last_updated": 1,
        "forecast_value": 1
    }))
    inventory_df = pd.DataFrame(inventory_docs)

    # -------------------------------------------------
    # Retrieve Warehouse Data (for ordering_cost)
    # -------------------------------------------------
    warehouse_collection = db["warehouse"]
    warehouse_docs = list(warehouse_collection.find({}, {
        "_id": 1,
        "ordering_cost": 1
    }))
    warehouses_df = pd.DataFrame(warehouse_docs)
    if not warehouses_df.empty:
        if "_id" in warehouses_df.columns:
            warehouses_df = warehouses_df.rename(columns={"_id": "warehouse_id"})

    # -------------------------------------------------
    # Retrieve Warehouse Transfers Data (for transfer cost)
    # -------------------------------------------------
    warehouse_transfers_collection = db["warehouse_transfers"]
    warehouse_transfers_docs = list(warehouse_transfers_collection.find({}, {
        "_id": 0,
        "source_warehouse_id": 1,
        "destination_warehouse_id": 1,
        "transfer_cost": 1
    }))
    warehouse_transfers_df = pd.DataFrame(warehouse_transfers_docs)

    # -------------------------------------------------
    # Merge Inventory with Warehouse Data to Include Ordering Cost
    # -------------------------------------------------
    default_ordering_cost = 2000.0  # Default ordering cost if warehouse data is missing
    if warehouses_df.empty or "ordering_cost" not in warehouses_df.columns:
        inventory_df["ordering_cost"] = default_ordering_cost
    else:
        inventory_df = pd.merge(inventory_df, warehouses_df[["warehouse_id", "ordering_cost"]],
                                  on="warehouse_id", how="left")
        inventory_df["ordering_cost"] = inventory_df["ordering_cost"].fillna(default_ordering_cost)

    # -------------------------------------------------
    # Step 1: Compute Dynamic Min Stock and Difference
    # -------------------------------------------------
    safety_factor = 0.2  # 20% safety factor
    inventory_df['dynamic_min_stock'] = (inventory_df['forecast_value'] * (1 + safety_factor)).round()
    inventory_df['diff'] = inventory_df['current_stock'] - inventory_df['dynamic_min_stock']

    # -------------------------------------------------
    # Step 2: Generate Individual Warehouse Recommendations (External Ordering)
    # -------------------------------------------------
    individual_recommendations = {}

    for idx, row in inventory_df.iterrows():
        prod = row["product_id"]
        ware = row["warehouse_id"]
        current_stock = row["current_stock"]
        forecast_value = row["forecast_value"]
        dynamic_min = row["dynamic_min_stock"]
        diff = row["diff"]
        order_cost = row["ordering_cost"]

        rec_message = ""
        external_order_cost_val = None

        if current_stock < dynamic_min:
            deficit = dynamic_min - current_stock
            external_order_cost_val = order_cost * deficit
            rec_message += f"Needs to order {deficit:.0f} units externally (Cost: {external_order_cost_val:.2f} rupees). "
        else:
            surplus = current_stock - dynamic_min
            rec_message += f"Has excess of {surplus:.0f} units; will attempt internal transfer. "

        individual_recommendations[(prod, ware)] = {
            "current_stock": current_stock,
            "forecast_value": forecast_value,
            "dynamic_min_stock": dynamic_min,
            "diff": diff,
            "external_order_cost": external_order_cost_val,
            "recommendation": rec_message
        }

    # -------------------------------------------------
    # Step 3: Generate Cross-Warehouse Transfer Recommendations
    # -------------------------------------------------
    transfer_recommendations = {}

    for prod, group in inventory_df.groupby("product_id"):
        surplus_list = []
        deficit_list = []
        for idx, row in group.iterrows():
            wh = row["warehouse_id"]
            diff_val = row["diff"]
            if diff_val > 0:
                surplus_list.append((wh, diff_val))
            elif diff_val < 0:
                deficit_list.append((wh, -diff_val))

        for d_idx, (def_wh, def_qty) in enumerate(deficit_list):
            while def_qty > 0 and surplus_list:
                candidate_transfers = []
                for s_idx, (surp_wh, surp_qty) in enumerate(surplus_list):
                    if surp_qty > 0:
                        transfer_qty = min(surp_qty, def_qty)
                        transfer_record = warehouse_transfers_df[
                            (warehouse_transfers_df["source_warehouse_id"] == surp_wh) &
                            (warehouse_transfers_df["destination_warehouse_id"] == def_wh)
                        ]
                        if not transfer_record.empty:
                            cost_per_unit = float(transfer_record.iloc[0]["transfer_cost"])
                        else:
                            cost_per_unit = 15.0  # Default transfer cost per unit
                        total_transfer_cost = cost_per_unit * transfer_qty
                        candidate_transfers.append((surp_wh, transfer_qty, total_transfer_cost, s_idx))
                if candidate_transfers:
                    best_candidate = min(candidate_transfers, key=lambda x: x[2])
                    best_surp_wh, transfer_qty, total_transfer_cost, best_idx = best_candidate
                    key = (prod, best_surp_wh, def_wh)
                    transfer_recommendations[key] = {
                        "source_warehouse": best_surp_wh,
                        "destination_warehouse": def_wh,
                        "transfer_quantity": transfer_qty,
                        "transfer_cost": total_transfer_cost,
                        "dynamic_min_stock": inventory_df[
                            (inventory_df["product_id"] == prod) & (inventory_df["warehouse_id"] == def_wh)
                        ]["dynamic_min_stock"].values[0]
                    }
                    surplus_list[best_idx] = (best_surp_wh, surplus_list[best_idx][1] - transfer_qty)
                    def_qty -= transfer_qty
                else:
                    break
            if def_qty > 0:
                transfer_recommendations[(prod, def_wh, "EXTERNAL")] = {
                    "destination_warehouse": def_wh,
                    "order_quantity": def_qty,
                    "external_order_cost": order_cost * def_qty,
                    "dynamic_min_stock": inventory_df[
                        (inventory_df["product_id"] == prod) & (inventory_df["warehouse_id"] == def_wh)
                    ]["dynamic_min_stock"].values[0]
                }

    # -------------------------------------------------
    # Return the Combined Recommendations as JSON
    # -------------------------------------------------
    response = {
        "individual_recommendations": {str(k): v for k, v in individual_recommendations.items()},
        "transfer_recommendations": {str(k): v for k, v in transfer_recommendations.items()}
    }
    return JSONResponse(content=response)

# -------------------------------------------------
# Expose the API using ngrok in Colab
# -------------------------------------------------
if __name__ == "__main__":
    public_url = ngrok.connect(8000).public_url
    print("Public URL:", public_url)
    uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# INFO:     Started server process [552]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# Public URL: https://b64e-35-238-196-193.ngrok-free.app
# INFO:     2409:40f4:410a:eae5:d5a6:37d4:79af:2eaa:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     2409:40f4:410a:eae5:d5a6:37d4:79af:2eaa:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS //inventory/optimization HTTP/1.1" 404 Not Found
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 405 Method Not Allowed
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 405 Method Not Allowed
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 405 Method Not Allowed
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 405 Method Not Allowed
# INFO:     2409:40f4:410a:eae5:607d:bd9f:f9e:4464:0 - "OPTIONS /inventory/optimization HTTP/1.1" 405 Method Not Allowed

# %%
# !pip install fastapi uvicorn pymongo pyngrok
# Out:
# Collecting fastapi
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pymongo
#   Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting pyngrok
#   Downloading pyngrok-7.2.3-py3-none-any.whl.metadata (8.7 kB)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi) (2.10.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (0.14.0)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.46.0,>=0.40.0->fastapi) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi) (1.3.1)
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 4.1 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.2 MB/s eta 0:00:00
# Downloading pymongo-4.11.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 22.3 MB/s eta 0:00:00
# Downloading pyngrok-7.2.3-py3-none-any.whl (23 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 25.4 MB/s eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: uvicorn, pyngrok, dnspython, starlette, pymongo, fastapi
# Successfully installed dnspython-2.7.0 fastapi-0.115.8 pymongo-4.11.1 pyngrok-7.2.3 starlette-0.45.3 uvicorn-0.34.0
